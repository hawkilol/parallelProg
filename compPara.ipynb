# %%
# !apt list --installed
# Out:
# Listing... Done
# adduser/focal,now 3.118ubuntu2 all [installed]
# adwaita-icon-theme/focal-updates,now 3.36.1-2ubuntu0.20.04.2 all [installed,automatic]
# apt-utils/focal-updates,now 2.0.9 amd64 [installed]
# apt/focal-updates,now 2.0.9 amd64 [installed]
# autoconf/focal,now 2.69-11.1 all [installed,automatic]
# automake/focal,now 1:1.16.1-4ubuntu6 all [installed,automatic]
# autotools-dev/focal,now 20180224.1 all [installed,automatic]
# base-files/now 11ubuntu5.6 amd64 [installed,upgradable to: 11ubuntu5.7]
# base-passwd/focal,now 3.5.47 amd64 [installed]
# bash/focal-updates,focal-security,now 5.0-6ubuntu1.2 amd64 [installed]
# binutils-common/now 2.34-6ubuntu1.4 amd64 [installed,upgradable to: 2.34-6ubuntu1.5]
# binutils-x86-64-linux-gnu/now 2.34-6ubuntu1.4 amd64 [installed,upgradable to: 2.34-6ubuntu1.5]
# binutils/now 2.34-6ubuntu1.4 amd64 [installed,upgradable to: 2.34-6ubuntu1.5]
# bsdmainutils/focal,now 11.1.2ubuntu3 amd64 [installed,automatic]
# bsdutils/focal-updates,focal-security,now 1:2.34-0.1ubuntu9.3 amd64 [installed]
# build-essential/focal-updates,now 12.8ubuntu1.1 amd64 [installed]
# bzip2/focal,now 1.0.8-2 amd64 [installed]
# ca-certificates-java/focal-updates,focal-security,now 20190405ubuntu1.1 all [installed,automatic]
# ca-certificates/focal-updates,focal-security,now 20230311ubuntu0.20.04.1 all [installed]
# clang-10/focal,now 1:10.0.0-4ubuntu1 amd64 [installed,automatic]
# clang/focal,now 1:10.0-50~exp1 amd64 [installed]
# clinfo/focal,now 2.2.18.04.06-1 amd64 [installed]
# cmake-data/focal-updates,now 3.16.3-1ubuntu1.20.04.1 all [installed,automatic]
# cmake/focal-updates,now 3.16.3-1ubuntu1.20.04.1 amd64 [installed]
# comerr-dev/focal-updates,focal-security,now 2.1-1.45.5-2ubuntu1.1 amd64 [installed,automatic]
# coreutils/focal,now 8.30-3ubuntu2 amd64 [installed]
# cpp-9/focal-updates,focal-security,now 9.4.0-1ubuntu1~20.04.1 amd64 [installed,automatic]
# cpp/focal,now 4:9.3.0-1ubuntu2 amd64 [installed,automatic]
# cuda-cccl-11-8/unknown,now 11.8.89-1 amd64 [installed,automatic]
# cuda-command-line-tools-11-8/unknown,now 11.8.0-1 amd64 [installed]
# cuda-compat-11-8/unknown,now 520.61.05-1 amd64 [installed]
# cuda-compiler-11-8/unknown,now 11.8.0-1 amd64 [installed,automatic]
# cuda-cudart-11-8/unknown,now 11.8.89-1 amd64 [installed]
# cuda-cudart-dev-11-8/unknown,now 11.8.89-1 amd64 [installed]
# cuda-cuobjdump-11-8/unknown,now 11.8.86-1 amd64 [installed,automatic]
# cuda-cupti-11-8/unknown,now 11.8.87-1 amd64 [installed,automatic]
# cuda-cupti-dev-11-8/unknown,now 11.8.87-1 amd64 [installed,automatic]
# cuda-cuxxfilt-11-8/unknown,now 11.8.86-1 amd64 [installed,automatic]
# cuda-driver-dev-11-8/unknown,now 11.8.89-1 amd64 [installed,automatic]
# cuda-gdb-11-8/unknown,now 11.8.86-1 amd64 [installed,automatic]
# cuda-libraries-11-8/unknown,now 11.8.0-1 amd64 [installed]
# cuda-libraries-dev-11-8/unknown,now 11.8.0-1 amd64 [installed]
# cuda-memcheck-11-8/unknown,now 11.8.86-1 amd64 [installed,automatic]
# cuda-minimal-build-11-8/unknown,now 11.8.0-1 amd64 [installed]
# cuda-nvcc-11-8/unknown,now 11.8.89-1 amd64 [installed,automatic]
# cuda-nvdisasm-11-8/unknown,now 11.8.86-1 amd64 [installed,automatic]
# cuda-nvml-dev-11-8/unknown,now 11.8.86-1 amd64 [installed]
# cuda-nvprof-11-8/unknown,now 11.8.87-1 amd64 [installed]
# cuda-nvprune-11-8/unknown,now 11.8.86-1 amd64 [installed,automatic]
# cuda-nvrtc-11-8/unknown,now 11.8.89-1 amd64 [installed,automatic]
# cuda-nvrtc-dev-11-8/unknown,now 11.8.89-1 amd64 [installed,automatic]
# cuda-nvtx-11-8/unknown,now 11.8.86-1 amd64 [installed]
# cuda-profiler-api-11-8/unknown,now 11.8.86-1 amd64 [installed,automatic]
# cuda-sanitizer-11-8/unknown,now 11.8.86-1 amd64 [installed,automatic]
# cuda-toolkit-11-8-config-common/unknown,now 11.8.89-1 all [installed,automatic]
# cuda-toolkit-11-config-common/unknown,now 11.8.89-1 all [installed,automatic]
# cuda-toolkit-config-common/unknown,now 12.0.146-1 all [installed,upgradable to: 12.1.105-1]
# curl/focal-updates,focal-security,now 7.68.0-1ubuntu2.18 amd64 [installed]
# dash/focal,now 0.5.10.2-6 amd64 [installed]
# dbus-user-session/focal-updates,focal-security,now 1.12.16-2ubuntu2.3 amd64 [installed,automatic]
# dbus/focal-updates,focal-security,now 1.12.16-2ubuntu2.3 amd64 [installed,automatic]
# dconf-gsettings-backend/focal,now 0.36.0-1 amd64 [installed,automatic]
# dconf-service/focal,now 0.36.0-1 amd64 [installed,automatic]
# debconf/focal,now 1.5.73 all [installed]
# debianutils/focal,now 4.9.1 amd64 [installed]
# default-libmysqlclient-dev/focal,now 1.0.5ubuntu2 amd64 [installed,automatic]
# diffutils/focal,now 1:3.7-3 amd64 [installed]
# dirmngr/focal-updates,focal-security,now 2.2.19-3ubuntu2.2 amd64 [installed]
# distro-info-data/focal-updates,now 0.43ubuntu1.13 all [installed,automatic]
# dpkg-dev/focal-updates,focal-security,now 1.19.7ubuntu3.2 all [installed,automatic]
# dpkg/focal-updates,focal-security,now 1.19.7ubuntu3.2 amd64 [installed]
# e2fsprogs/focal-updates,focal-security,now 1.45.5-2ubuntu1.1 amd64 [installed]
# fdisk/focal-updates,focal-security,now 2.34-0.1ubuntu9.3 amd64 [installed]
# ffmpeg/focal-updates,focal-security,now 7:4.2.7-0ubuntu0.1 amd64 [installed]
# file/focal,now 1:5.38-4 amd64 [installed]
# findutils/focal,now 4.7.0-1ubuntu1 amd64 [installed]
# fio/focal,now 3.16-1 amd64 [installed]
# fontconfig-config/focal,now 2.13.1-2ubuntu3 all [installed,automatic]
# fontconfig/focal,now 2.13.1-2ubuntu3 amd64 [installed,automatic]
# fonts-humor-sans/focal,now 1.0-3 all [installed]
# fonts-liberation/focal,now 1:1.07.4-11 all [installed]
# fuse/focal,now 2.9.9-3 amd64 [installed]
# g++-9/focal-updates,focal-security,now 9.4.0-1ubuntu1~20.04.1 amd64 [installed,automatic]
# g++/focal,now 4:9.3.0-1ubuntu2 amd64 [installed,automatic]
# gcc-10-base/focal-updates,focal-security,now 10.3.0-1ubuntu1~20.04 amd64 [installed]
# gcc-9-base/focal-updates,focal-security,now 9.4.0-1ubuntu1~20.04.1 amd64 [installed,automatic]
# gcc-9/focal-updates,focal-security,now 9.4.0-1ubuntu1~20.04.1 amd64 [installed,automatic]
# gcc/focal,now 4:9.3.0-1ubuntu2 amd64 [installed,automatic]
# gdal-data/focal,now 3.3.2+dfsg-2~focal2 all [installed,automatic]
# gfortran-9/focal-updates,focal-security,now 9.4.0-1ubuntu1~20.04.1 amd64 [installed,automatic]
# gfortran/focal,now 4:9.3.0-1ubuntu2 amd64 [installed]
# gir1.2-glib-2.0/focal-updates,now 1.64.1-1~ubuntu20.04.1 amd64 [installed,automatic]
# gir1.2-packagekitglib-1.0/focal-updates,focal-security,now 1.1.13-2ubuntu1.1 amd64 [installed,automatic]
# git-lfs/focal,now 2.9.2-1 amd64 [installed]
# git-man/focal-updates,focal-security,now 1:2.25.1-1ubuntu3.11 all [installed,automatic]
# git/focal-updates,focal-security,now 1:2.25.1-1ubuntu3.11 amd64 [installed]
# glib-networking-common/focal-updates,focal-security,now 2.64.2-1ubuntu0.1 all [installed,automatic]
# glib-networking-services/focal-updates,focal-security,now 2.64.2-1ubuntu0.1 amd64 [installed,automatic]
# glib-networking/focal-updates,focal-security,now 2.64.2-1ubuntu0.1 amd64 [installed,automatic]
# gnupg-l10n/focal-updates,focal-security,now 2.2.19-3ubuntu2.2 all [installed,automatic]
# gnupg-utils/focal-updates,focal-security,now 2.2.19-3ubuntu2.2 amd64 [installed,automatic]
# gnupg2/focal-updates,focal-security,now 2.2.19-3ubuntu2.2 all [installed]
# gnupg/focal-updates,focal-security,now 2.2.19-3ubuntu2.2 all [installed,automatic]
# google-perftools/focal,now 2.7-1ubuntu2 all [installed]
# gpg-agent/focal-updates,focal-security,now 2.2.19-3ubuntu2.2 amd64 [installed,automatic]
# gpg-wks-client/focal-updates,focal-security,now 2.2.19-3ubuntu2.2 amd64 [installed,automatic]
# gpg-wks-server/focal-updates,focal-security,now 2.2.19-3ubuntu2.2 amd64 [installed,automatic]
# gpg/focal-updates,focal-security,now 2.2.19-3ubuntu2.2 amd64 [installed,automatic]
# gpgconf/focal-updates,focal-security,now 2.2.19-3ubuntu2.2 amd64 [installed,automatic]
# gpgsm/focal-updates,focal-security,now 2.2.19-3ubuntu2.2 amd64 [installed,automatic]
# gpgv/focal-updates,focal-security,now 2.2.19-3ubuntu2.2 amd64 [installed]
# graphviz/focal,now 2.42.2-3build2 amd64 [installed]
# grep/focal,now 3.4-1 amd64 [installed]
# groff-base/focal,now 1.22.4-4build1 amd64 [installed,automatic]
# gsettings-desktop-schemas/focal,now 3.36.0-1ubuntu1 all [installed,automatic]
# gtk-update-icon-cache/focal-updates,now 3.24.20-0ubuntu1.1 amd64 [installed,automatic]
# gzip/focal-updates,focal-security,now 1.10-0ubuntu4.1 amd64 [installed]
# hdf5-helpers/focal,now 1.10.4+repack-11ubuntu1 amd64 [installed,automatic]
# hicolor-icon-theme/focal,now 0.17-2 all [installed,automatic]
# hostname/focal,now 3.23 amd64 [installed]
# humanity-icon-theme/focal,now 0.6.15 all [installed,automatic]
# ibverbs-providers/focal,now 28.0-1ubuntu1 amd64 [installed,automatic]
# icu-devtools/focal-updates,focal-security,now 66.1-2ubuntu2.1 amd64 [installed,automatic]
# init-system-helpers/focal,now 1.57 all [installed]
# iproute2/focal,now 5.5.0-1ubuntu1 amd64 [installed,automatic]
# iso-codes/focal,now 4.4-1 all [installed,automatic]
# java-common/focal,now 0.72 all [installed,automatic]
# kmod/focal-updates,now 27-1ubuntu2.1 amd64 [installed]
# krb5-multidev/focal-updates,focal-security,now 1.17-6ubuntu4.3 amd64 [installed,automatic]
# less/focal-updates,now 551-1ubuntu0.1 amd64 [installed]
# lib32gcc-s1/focal-updates,focal-security,now 10.3.0-1ubuntu1~20.04 amd64 [installed,automatic]
# lib32stdc++6/focal-updates,focal-security,now 10.3.0-1ubuntu1~20.04 amd64 [installed,automatic]
# libacl1/focal,now 2.2.53-6 amd64 [installed]
# libaec-dev/focal,now 1.0.4-1 amd64 [installed,automatic]
# libaec0/focal,now 1.0.4-1 amd64 [installed,automatic]
# libaio1/focal,now 0.3.112-5 amd64 [installed,automatic]
# libann0/focal,now 1.1.2+doc-7build1 amd64 [installed,automatic]
# libaom0/focal,now 1.0.0.errata1-3build1 amd64 [installed,automatic]
# libapparmor1/focal-updates,now 2.13.3-7ubuntu5.2 amd64 [installed,automatic]
# libappstream4/focal,now 0.12.10-2 amd64 [installed,automatic]
# libapt-pkg-dev/focal-updates,now 2.0.9 amd64 [installed]
# libapt-pkg6.0/focal-updates,now 2.0.9 amd64 [installed]
# libarchive13/focal-updates,focal-security,now 3.4.0-2ubuntu1.2 amd64 [installed,automatic]
# libargon2-1/focal,now 0~20171227-0.2 amd64 [installed,automatic]
# libarmadillo-dev/focal,now 1:9.800.4+dfsg-1build1 amd64 [installed,automatic]
# libarmadillo9/focal,now 1:9.800.4+dfsg-1build1 amd64 [installed,automatic]
# libarpack2-dev/focal,now 3.7.0-3 amd64 [installed,automatic]
# libarpack2/focal,now 3.7.0-3 amd64 [installed,automatic]
# libasan5/focal-updates,focal-security,now 9.4.0-1ubuntu1~20.04.1 amd64 [installed,automatic]
# libasn1-8-heimdal/now 7.7.0+dfsg-1ubuntu1.3 amd64 [installed,upgradable to: 7.7.0+dfsg-1ubuntu1.4]
# libasound2-data/focal-updates,now 1.2.2-2.1ubuntu2.5 all [installed,automatic]
# libasound2-dev/focal-updates,now 1.2.2-2.1ubuntu2.5 amd64 [installed]
# libasound2/focal-updates,now 1.2.2-2.1ubuntu2.5 amd64 [installed,automatic]
# libass9/focal,now 1:0.14.0-2 amd64 [installed,automatic]
# libassuan0/focal,now 2.5.3-7ubuntu2 amd64 [installed,automatic]
# libasyncns0/focal,now 0.8-6 amd64 [installed,automatic]
# libatk-bridge2.0-0/focal-updates,now 2.34.2-0ubuntu2~20.04.1 amd64 [installed,automatic]
# libatk1.0-0/focal,now 2.35.1-1ubuntu2 amd64 [installed,automatic]
# libatk1.0-data/focal,now 2.35.1-1ubuntu2 all [installed,automatic]
# libatlas-base-dev/focal,now 3.10.3-8ubuntu7 amd64 [installed]
# libatlas3-base/focal,now 3.10.3-8ubuntu7 amd64 [installed,automatic]
# libatomic1/focal-updates,focal-security,now 10.3.0-1ubuntu1~20.04 amd64 [installed,automatic]
# libatspi2.0-0/focal,now 2.36.0-2 amd64 [installed,automatic]
# libattr1/focal,now 1:2.4.48-5 amd64 [installed]
# libaudit-common/focal,now 1:2.8.5-2ubuntu6 all [installed]
# libaudit1/focal,now 1:2.8.5-2ubuntu6 amd64 [installed]
# libavahi-client3/focal-updates,focal-security,now 0.7-4ubuntu7.2 amd64 [installed,automatic]
# libavahi-common-data/focal-updates,focal-security,now 0.7-4ubuntu7.2 amd64 [installed,automatic]
# libavahi-common3/focal-updates,focal-security,now 0.7-4ubuntu7.2 amd64 [installed,automatic]
# libavc1394-0/focal,now 0.5.4-5 amd64 [installed,automatic]
# libavcodec-dev/focal-updates,focal-security,now 7:4.2.7-0ubuntu0.1 amd64 [installed,automatic]
# libavcodec58/focal-updates,focal-security,now 7:4.2.7-0ubuntu0.1 amd64 [installed,automatic]
# libavdevice58/focal-updates,focal-security,now 7:4.2.7-0ubuntu0.1 amd64 [installed]
# libavfilter7/focal-updates,focal-security,now 7:4.2.7-0ubuntu0.1 amd64 [installed,automatic]
# libavformat-dev/focal-updates,focal-security,now 7:4.2.7-0ubuntu0.1 amd64 [installed,automatic]
# libavformat58/focal-updates,focal-security,now 7:4.2.7-0ubuntu0.1 amd64 [installed,automatic]
# libavresample-dev/focal-updates,focal-security,now 7:4.2.7-0ubuntu0.1 amd64 [installed,automatic]
# libavresample4/focal-updates,focal-security,now 7:4.2.7-0ubuntu0.1 amd64 [installed,automatic]
# libavutil-dev/focal-updates,focal-security,now 7:4.2.7-0ubuntu0.1 amd64 [installed,automatic]
# libavutil56/focal-updates,focal-security,now 7:4.2.7-0ubuntu0.1 amd64 [installed,automatic]
# libbinutils/now 2.34-6ubuntu1.4 amd64 [installed,upgradable to: 2.34-6ubuntu1.5]
# libblkid1/focal-updates,focal-security,now 2.34-0.1ubuntu9.3 amd64 [installed]
# libblocksruntime-dev/focal,now 0.4.1-1.1 amd64 [installed]
# libblocksruntime0/focal,now 0.4.1-1.1 amd64 [installed,automatic]
# libbluray2/focal,now 1:1.2.0-1 amd64 [installed,automatic]
# libboost-all-dev/focal,now 1.71.0.0ubuntu2 amd64 [installed]
# libboost-atomic-dev/focal,now 1.71.0.0ubuntu2 amd64 [installed,automatic]
# libboost-atomic1.71-dev/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]
# libboost-atomic1.71.0/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]
# libboost-chrono-dev/focal,now 1.71.0.0ubuntu2 amd64 [installed,automatic]
# libboost-chrono1.71-dev/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]
# libboost-chrono1.71.0/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]
# libboost-container-dev/focal,now 1.71.0.0ubuntu2 amd64 [installed,automatic]
# libboost-container1.71-dev/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]
# libboost-container1.71.0/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]
# libboost-context-dev/focal,now 1.71.0.0ubuntu2 amd64 [installed,automatic]
# libboost-context1.71-dev/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]
# libboost-context1.71.0/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]
# libboost-coroutine-dev/focal,now 1.71.0.0ubuntu2 amd64 [installed,automatic]
# libboost-coroutine1.71-dev/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]
# libboost-coroutine1.71.0/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]
# libboost-date-time-dev/focal,now 1.71.0.0ubuntu2 amd64 [installed,automatic]
# libboost-date-time1.71-dev/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]
# libboost-date-time1.71.0/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]
# libboost-dev/focal,now 1.71.0.0ubuntu2 amd64 [installed,automatic]
# libboost-exception-dev/focal,now 1.71.0.0ubuntu2 amd64 [installed,automatic]
# libboost-exception1.71-dev/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]
# libboost-fiber-dev/focal,now 1.71.0.0ubuntu2 amd64 [installed,automatic]
# libboost-fiber1.71-dev/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]
# libboost-fiber1.71.0/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]
# libboost-filesystem-dev/focal,now 1.71.0.0ubuntu2 amd64 [installed,automatic]
# libboost-filesystem1.71-dev/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]
# libboost-filesystem1.71.0/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]
# libboost-graph-dev/focal,now 1.71.0.0ubuntu2 amd64 [installed,automatic]
# libboost-graph-parallel-dev/focal,now 1.71.0.0ubuntu2 amd64 [installed,automatic]
# libboost-graph-parallel1.71-dev/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]
# libboost-graph-parallel1.71.0/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]
# libboost-graph1.71-dev/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]
# libboost-graph1.71.0/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]
# libboost-iostreams-dev/focal,now 1.71.0.0ubuntu2 amd64 [installed,automatic]
# libboost-iostreams1.71-dev/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]
# libboost-iostreams1.71.0/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]
# libboost-locale-dev/focal,now 1.71.0.0ubuntu2 amd64 [installed,automatic]
# libboost-locale1.71-dev/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]
# libboost-locale1.71.0/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]
# libboost-log-dev/focal,now 1.71.0.0ubuntu2 amd64 [installed,automatic]
# libboost-log1.71-dev/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]
# libboost-log1.71.0/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]
# libboost-math-dev/focal,now 1.71.0.0ubuntu2 amd64 [installed,automatic]
# libboost-math1.71-dev/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]
# libboost-math1.71.0/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]
# libboost-mpi-dev/focal,now 1.71.0.0ubuntu2 amd64 [installed,automatic]
# libboost-mpi-python-dev/focal,now 1.71.0.0ubuntu2 amd64 [installed,automatic]
# libboost-mpi-python1.71-dev/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]
# libboost-mpi-python1.71.0/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]
# libboost-mpi1.71-dev/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]
# libboost-mpi1.71.0/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]
# libboost-numpy-dev/focal,now 1.71.0.0ubuntu2 amd64 [installed,automatic]
# libboost-numpy1.71-dev/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]
# libboost-numpy1.71.0/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]
# libboost-program-options-dev/focal,now 1.71.0.0ubuntu2 amd64 [installed,automatic]
# libboost-program-options1.71-dev/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]
# libboost-program-options1.71.0/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]
# libboost-python-dev/focal,now 1.71.0.0ubuntu2 amd64 [installed,automatic]
# libboost-python1.71-dev/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]
# libboost-python1.71.0/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]
# libboost-random-dev/focal,now 1.71.0.0ubuntu2 amd64 [installed,automatic]
# libboost-random1.71-dev/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]
# libboost-random1.71.0/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]
# libboost-regex-dev/focal,now 1.71.0.0ubuntu2 amd64 [installed,automatic]
# libboost-regex1.71-dev/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]
# libboost-regex1.71.0/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]
# libboost-serialization-dev/focal,now 1.71.0.0ubuntu2 amd64 [installed,automatic]
# libboost-serialization1.71-dev/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]
# libboost-serialization1.71.0/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]
# libboost-stacktrace-dev/focal,now 1.71.0.0ubuntu2 amd64 [installed,automatic]
# libboost-stacktrace1.71-dev/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]
# libboost-stacktrace1.71.0/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]
# libboost-system-dev/focal,now 1.71.0.0ubuntu2 amd64 [installed,automatic]
# libboost-system1.71-dev/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]
# libboost-system1.71.0/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]
# libboost-test-dev/focal,now 1.71.0.0ubuntu2 amd64 [installed,automatic]
# libboost-test1.71-dev/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]
# libboost-test1.71.0/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]
# libboost-thread-dev/focal,now 1.71.0.0ubuntu2 amd64 [installed,automatic]
# libboost-thread1.71-dev/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]
# libboost-thread1.71.0/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]
# libboost-timer-dev/focal,now 1.71.0.0ubuntu2 amd64 [installed,automatic]
# libboost-timer1.71-dev/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]
# libboost-timer1.71.0/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]
# libboost-tools-dev/focal,now 1.71.0.0ubuntu2 amd64 [installed,automatic]
# libboost-type-erasure-dev/focal,now 1.71.0.0ubuntu2 amd64 [installed,automatic]
# libboost-type-erasure1.71-dev/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]
# libboost-type-erasure1.71.0/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]
# libboost-wave-dev/focal,now 1.71.0.0ubuntu2 amd64 [installed,automatic]
# libboost-wave1.71-dev/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]
# libboost-wave1.71.0/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]
# libboost1.71-dev/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]
# libboost1.71-tools-dev/focal,now 1.71.0-6ubuntu6 amd64 [installed,automatic]
# libbrotli1/focal-updates,focal-security,now 1.0.7-6ubuntu0.1 amd64 [installed,automatic]
# libbs2b0/focal,now 3.1.0+dfsg-2.2build1 amd64 [installed,automatic]
# libbsd0/focal,now 0.10.0-1 amd64 [installed,automatic]
# libbz2-1.0/focal,now 1.0.8-2 amd64 [installed]
# libbz2-dev/focal,now 1.0.8-2 amd64 [installed,automatic]
# libc-bin/focal-updates,now 2.31-0ubuntu9.9 amd64 [installed]
# libc-dev-bin/focal-updates,now 2.31-0ubuntu9.9 amd64 [installed,automatic]
# libc6-dev/focal-updates,now 2.31-0ubuntu9.9 amd64 [installed,automatic]
# libc6-i386/focal-updates,now 2.31-0ubuntu9.9 amd64 [installed,automatic]
# libc6/focal-updates,now 2.31-0ubuntu9.9 amd64 [installed]
# libcaca0/focal-updates,focal-security,now 0.99.beta19-2.1ubuntu1.20.04.2 amd64 [installed,automatic]
# libcairo-gobject2/focal,now 1.16.0-4ubuntu1 amd64 [installed,automatic]
# libcairo2/focal,now 1.16.0-4ubuntu1 amd64 [installed,automatic]
# libcanberra0/focal,now 0.30-7ubuntu1 amd64 [installed,automatic]
# libcap-ng0/focal,now 0.7.9-2.1build1 amd64 [installed]
# libcap2-bin/focal,now 1:2.32-1 amd64 [installed,automatic]
# libcap2/focal,now 1:2.32-1 amd64 [installed,automatic]
# libcbor0.6/focal,now 0.6.0-0ubuntu1 amd64 [installed,automatic]
# libcc1-0/focal-updates,focal-security,now 10.3.0-1ubuntu1~20.04 amd64 [installed,automatic]
# libcdio-cdda2/focal,now 10.2+2.0.0-1 amd64 [installed,automatic]
# libcdio-paranoia2/focal,now 10.2+2.0.0-1 amd64 [installed,automatic]
# libcdio18/focal,now 2.0.0-2 amd64 [installed,automatic]
# libcdt5/focal,now 2.42.2-3build2 amd64 [installed,automatic]
# libcfitsio-dev/focal,now 3.470-3 amd64 [installed,automatic]
# libcfitsio8/focal,now 3.470-3 amd64 [installed,automatic]
# libcgraph6/focal,now 2.42.2-3build2 amd64 [installed,automatic]
# libcharls-dev/focal,now 2.0.0+dfsg-1build1 amd64 [installed,automatic]
# libcharls2/focal,now 2.0.0+dfsg-1build1 amd64 [installed,automatic]
# libchromaprint1/focal,now 1.4.3-3build1 amd64 [installed,automatic]
# libclang-common-10-dev/focal,now 1:10.0.0-4ubuntu1 amd64 [installed,automatic]
# libclang-cpp10/focal,now 1:10.0.0-4ubuntu1 amd64 [installed,automatic]
# libclang1-10/focal,now 1:10.0.0-4ubuntu1 amd64 [installed,automatic]
# libcodec2-0.9/focal,now 0.9.2-2 amd64 [installed,automatic]
# libcolord2/focal,now 1.4.4-2 amd64 [installed,automatic]
# libcom-err2/focal-updates,focal-security,now 1.45.5-2ubuntu1.1 amd64 [installed]
# libcrypt-dev/focal,now 1:4.4.10-10ubuntu4 amd64 [installed,automatic]
# libcrypt1/focal,now 1:4.4.10-10ubuntu4 amd64 [installed]
# libcryptsetup12/focal-updates,focal-security,now 2:2.2.2-3ubuntu2.4 amd64 [installed,automatic]
# libctf-nobfd0/now 2.34-6ubuntu1.4 amd64 [installed,upgradable to: 2.34-6ubuntu1.5]
# libctf0/now 2.34-6ubuntu1.4 amd64 [installed,upgradable to: 2.34-6ubuntu1.5]
# libcublas-11-8/unknown,now 11.11.3.6-1 amd64 [installed]
# libcublas-dev-11-8/unknown,now 11.11.3.6-1 amd64 [installed]
# libcudnn8-dev/unknown,now 8.7.0.84-1+cuda11.8 amd64 [installed,upgradable to: 8.9.2.26-1+cuda12.1]
# libcudnn8/unknown,now 8.7.0.84-1+cuda11.8 amd64 [installed,upgradable to: 8.9.2.26-1+cuda12.1]
# libcufft-11-8/unknown,now 10.9.0.58-1 amd64 [installed,automatic]
# libcufft-dev-11-8/unknown,now 10.9.0.58-1 amd64 [installed,automatic]
# libcufile-11-8/unknown,now 1.4.0.31-1 amd64 [installed,automatic]
# libcufile-dev-11-8/unknown,now 1.4.0.31-1 amd64 [installed,automatic]
# libcups2/focal-updates,focal-security,now 2.3.1-9ubuntu1.3 amd64 [installed,automatic]
# libcurand-11-8/unknown,now 10.3.0.86-1 amd64 [installed,automatic]
# libcurand-dev-11-8/unknown,now 10.3.0.86-1 amd64 [installed,automatic]
# libcurl3-gnutls/focal-updates,focal-security,now 7.68.0-1ubuntu2.18 amd64 [installed,automatic]
# libcurl4-openssl-dev/focal-updates,focal-security,now 7.68.0-1ubuntu2.18 amd64 [installed]
# libcurl4/focal-updates,focal-security,now 7.68.0-1ubuntu2.18 amd64 [installed]
# libcusolver-11-8/unknown,now 11.4.1.48-1 amd64 [installed,automatic]
# libcusolver-dev-11-8/unknown,now 11.4.1.48-1 amd64 [installed,automatic]
# libcusparse-11-8/unknown,now 11.7.5.86-1 amd64 [installed]
# libcusparse-dev-11-8/unknown,now 11.7.5.86-1 amd64 [installed]
# libdatrie1/focal,now 0.2.12-3 amd64 [installed,automatic]
# libdb5.3/focal,now 5.3.28+dfsg1-0.6ubuntu2 amd64 [installed]
# libdbus-1-3/focal-updates,focal-security,now 1.12.16-2ubuntu2.3 amd64 [installed,automatic]
# libdc1394-22-dev/focal,now 2.2.5-2.1 amd64 [installed,automatic]
# libdc1394-22/focal,now 2.2.5-2.1 amd64 [installed,automatic]
# libdconf1/focal,now 0.36.0-1 amd64 [installed,automatic]
# libde265-0/focal,now 1.0.4-1build1 amd64 [installed,automatic]
# libdebconfclient0/focal,now 0.251ubuntu1 amd64 [installed]
# libdeflate-dev/focal,now 1.5-3 amd64 [installed,automatic]
# libdeflate0/focal,now 1.5-3 amd64 [installed,automatic]
# libdevmapper1.02.1/focal,now 2:1.02.167-1ubuntu1 amd64 [installed,automatic]
# libdouble-conversion3/focal,now 3.1.5-4ubuntu1 amd64 [installed,automatic]
# libdpkg-perl/focal-updates,focal-security,now 1.19.7ubuntu3.2 all [installed,automatic]
# libdrm-amdgpu1/focal-updates,focal-security,now 2.4.107-8ubuntu1~20.04.2 amd64 [installed,automatic]
# libdrm-common/focal-updates,focal-security,now 2.4.107-8ubuntu1~20.04.2 all [installed,automatic]
# libdrm-intel1/focal-updates,focal-security,now 2.4.107-8ubuntu1~20.04.2 amd64 [installed,automatic]
# libdrm-nouveau2/focal-updates,focal-security,now 2.4.107-8ubuntu1~20.04.2 amd64 [installed,automatic]
# libdrm-radeon1/focal-updates,focal-security,now 2.4.107-8ubuntu1~20.04.2 amd64 [installed,automatic]
# libdrm2/focal-updates,focal-security,now 2.4.107-8ubuntu1~20.04.2 amd64 [installed,automatic]
# libedit2/focal,now 3.1-20191231-1 amd64 [installed,automatic]
# libegl-dev/focal-updates,focal-security,now 1.3.2-1~ubuntu0.20.04.2 amd64 [installed,automatic]
# libegl-mesa0/focal-updates,focal-security,now 21.2.6-0ubuntu0.1~20.04.2 amd64 [installed,automatic]
# libegl1/focal-updates,focal-security,now 1.3.2-1~ubuntu0.20.04.2 amd64 [installed]
# libelf1/focal,now 0.176-1.1build1 amd64 [installed,automatic]
# libepoxy0/focal,now 1.5.4-1 amd64 [installed,automatic]
# liberror-perl/focal,now 0.17029-1 all [installed,automatic]
# libevdev2/focal-updates,focal-security,now 1.9.0+dfsg-1ubuntu0.2 amd64 [installed,automatic]
# libevent-2.1-7/focal,now 2.1.11-stable-1 amd64 [installed,automatic]
# libevent-core-2.1-7/focal,now 2.1.11-stable-1 amd64 [installed,automatic]
# libevent-dev/focal,now 2.1.11-stable-1 amd64 [installed,automatic]
# libevent-extra-2.1-7/focal,now 2.1.11-stable-1 amd64 [installed,automatic]
# libevent-openssl-2.1-7/focal,now 2.1.11-stable-1 amd64 [installed,automatic]
# libevent-pthreads-2.1-7/focal,now 2.1.11-stable-1 amd64 [installed,automatic]
# libexif-dev/focal-updates,focal-security,now 0.6.21-6ubuntu0.4 amd64 [installed,automatic]
# libexif12/focal-updates,focal-security,now 0.6.21-6ubuntu0.4 amd64 [installed,automatic]
# libexpat1-dev/focal-updates,focal-security,now 2.2.9-1ubuntu0.6 amd64 [installed,automatic]
# libexpat1/focal-updates,focal-security,now 2.2.9-1ubuntu0.6 amd64 [installed,automatic]
# libext2fs2/focal-updates,focal-security,now 1.45.5-2ubuntu1.1 amd64 [installed]
# libfabric1/focal-updates,now 1.6.2-3ubuntu0.1 amd64 [installed,automatic]
# libfdisk1/focal-updates,focal-security,now 2.34-0.1ubuntu9.3 amd64 [installed]
# libffi7/focal,now 3.3-4 amd64 [installed]
# libfftw3-double3/focal,now 3.3.8-2ubuntu1 amd64 [installed,automatic]
# libfido2-1/focal,now 1.3.1-1ubuntu2 amd64 [installed,automatic]
# libflac-dev/focal-updates,focal-security,now 1.3.3-1ubuntu0.1 amd64 [installed,automatic]
# libflac8/focal-updates,focal-security,now 1.3.3-1ubuntu0.1 amd64 [installed,automatic]
# libflite1/focal,now 2.1-release-3 amd64 [installed,automatic]
# libfontconfig1-dev/focal,now 2.13.1-2ubuntu3 amd64 [installed,automatic]
# libfontconfig1/focal,now 2.13.1-2ubuntu3 amd64 [installed,automatic]
# libfreetype-dev/focal-updates,focal-security,now 2.10.1-2ubuntu0.3 amd64 [installed,automatic]
# libfreetype6-dev/focal-updates,focal-security,now 2.10.1-2ubuntu0.3 amd64 [installed]
# libfreetype6/focal-updates,focal-security,now 2.10.1-2ubuntu0.3 amd64 [installed,automatic]
# libfreexl-dev/focal,now 1.0.5-3 amd64 [installed,automatic]
# libfreexl1/focal,now 1.0.5-3 amd64 [installed,automatic]
# libfribidi0/focal-updates,focal-security,now 1.0.8-2ubuntu0.1 amd64 [installed,automatic]
# libfuse2/focal,now 2.9.9-3 amd64 [installed,automatic]
# libfyba-dev/focal,now 4.1.1-6build1 amd64 [installed,automatic]
# libfyba0/focal,now 4.1.1-6build1 amd64 [installed,automatic]
# libgbm1/focal-updates,focal-security,now 21.2.6-0ubuntu0.1~20.04.2 amd64 [installed,automatic]
# libgc1c2/focal,now 1:7.6.4-0.4ubuntu1 amd64 [installed,automatic]
# libgcc-9-dev/focal-updates,focal-security,now 9.4.0-1ubuntu1~20.04.1 amd64 [installed,automatic]
# libgcc-s1/focal-updates,focal-security,now 10.3.0-1ubuntu1~20.04 amd64 [installed]
# libgcrypt20-dev/focal-updates,focal-security,now 1.8.5-5ubuntu1.1 amd64 [installed,automatic]
# libgcrypt20/focal-updates,focal-security,now 1.8.5-5ubuntu1.1 amd64 [installed]
# libgd3/focal-updates,focal-security,now 2.2.5-5.2ubuntu2.1 amd64 [installed,automatic]
# libgdal-dev/focal,now 3.3.2+dfsg-2~focal2 amd64 [installed]
# libgdal29/focal,now 3.3.2+dfsg-2~focal2 amd64 [installed,automatic]
# libgdbm-compat4/focal,now 1.18.1-5 amd64 [installed,automatic]
# libgdbm6/focal,now 1.18.1-5 amd64 [installed,automatic]
# libgdcm-dev/focal,now 3.0.5-1.1ubuntu2 amd64 [installed,automatic]
# libgdcm3.0/focal,now 3.0.5-1.1ubuntu2 amd64 [installed,automatic]
# libgdk-pixbuf2.0-0/focal-updates,focal-security,now 2.40.0+dfsg-3ubuntu0.4 amd64 [installed,automatic]
# libgdk-pixbuf2.0-common/focal-updates,focal-security,now 2.40.0+dfsg-3ubuntu0.4 all [installed,automatic]
# libgeos-3.9.1/focal,now 3.9.1-1~focal0 amd64 [installed,automatic]
# libgeos-c1v5/focal,now 3.9.1-1~focal0 amd64 [installed,automatic]
# libgeos-dev/focal,now 3.9.1-1~focal0 amd64 [installed,automatic]
# libgeotiff-dev/focal,now 1.7.0-2~focal0 amd64 [installed,automatic]
# libgeotiff5/focal,now 1.7.0-2~focal0 amd64 [installed,automatic]
# libgfapi0/focal,now 7.2-2build1 amd64 [installed,automatic]
# libgfortran-9-dev/focal-updates,focal-security,now 9.4.0-1ubuntu1~20.04.1 amd64 [installed,automatic]
# libgfortran5/focal-updates,focal-security,now 10.3.0-1ubuntu1~20.04 amd64 [installed,automatic]
# libgfrpc0/focal,now 7.2-2build1 amd64 [installed,automatic]
# libgfxdr0/focal,now 7.2-2build1 amd64 [installed,automatic]
# libgif-dev/focal,now 5.1.9-1 amd64 [installed,automatic]
# libgif7/focal,now 5.1.9-1 amd64 [installed,automatic]
# libgirepository-1.0-1/focal-updates,now 1.64.1-1~ubuntu20.04.1 amd64 [installed,automatic]
# libgit2-28/focal,now 0.28.4+dfsg.1-2 amd64 [installed,automatic]
# libgit2-dev/focal,now 0.28.4+dfsg.1-2 amd64 [installed]
# libgl-dev/focal-updates,focal-security,now 1.3.2-1~ubuntu0.20.04.2 amd64 [installed,automatic]
# libgl1-mesa-dri/focal-updates,focal-security,now 21.2.6-0ubuntu0.1~20.04.2 amd64 [installed,automatic]
# libgl1/focal-updates,focal-security,now 1.3.2-1~ubuntu0.20.04.2 amd64 [installed]
# libgl2ps1.4/focal,now 1.4.0+dfsg1-2 amd64 [installed,automatic]
# libglapi-mesa/focal-updates,focal-security,now 21.2.6-0ubuntu0.1~20.04.2 amd64 [installed,automatic]
# libgles2/focal-updates,focal-security,now 1.3.2-1~ubuntu0.20.04.2 amd64 [installed]
# libglib2.0-0/focal-updates,now 2.64.6-1~ubuntu20.04.4 amd64 [installed,automatic]
# libglib2.0-bin/focal-updates,now 2.64.6-1~ubuntu20.04.4 amd64 [installed,automatic]
# libglib2.0-data/focal-updates,now 2.64.6-1~ubuntu20.04.4 all [installed,automatic]
# libglu1-mesa-dev/focal,now 9.0.1-1build1 amd64 [installed,automatic]
# libglu1-mesa/focal,now 9.0.1-1build1 amd64 [installed,automatic]
# libglusterfs0/focal,now 7.2-2build1 amd64 [installed,automatic]
# libglvnd0/focal-updates,focal-security,now 1.3.2-1~ubuntu0.20.04.2 amd64 [installed]
# libglx-dev/focal-updates,focal-security,now 1.3.2-1~ubuntu0.20.04.2 amd64 [installed,automatic]
# libglx-mesa0/focal-updates,focal-security,now 21.2.6-0ubuntu0.1~20.04.2 amd64 [installed,automatic]
# libglx0/focal-updates,focal-security,now 1.3.2-1~ubuntu0.20.04.2 amd64 [installed,automatic]
# libgme0/focal,now 0.6.2-1build1 amd64 [installed,automatic]
# libgmp10/focal-updates,focal-security,now 2:6.2.0+dfsg-4ubuntu0.1 amd64 [installed]
# libgnutls30/now 3.6.13-2ubuntu1.7 amd64 [installed,upgradable to: 3.6.13-2ubuntu1.8]
# libgomp1/focal-updates,focal-security,now 10.3.0-1ubuntu1~20.04 amd64 [installed,automatic]
# libgoogle-perftools4/focal,now 2.7-1ubuntu2 amd64 [installed,automatic]
# libgpg-error-dev/focal,now 1.37-1 amd64 [installed,automatic]
# libgpg-error0/focal,now 1.37-1 amd64 [installed]
# libgphoto2-6/focal-updates,now 2.5.25-0ubuntu0.1 amd64 [installed,automatic]
# libgphoto2-dev/focal-updates,now 2.5.25-0ubuntu0.1 amd64 [installed,automatic]
# libgphoto2-port12/focal-updates,now 2.5.25-0ubuntu0.1 amd64 [installed,automatic]
# libgpm2/focal,now 1.20.7-5 amd64 [installed,automatic]
# libgraphite2-3/focal,now 1.3.13-11build1 amd64 [installed,automatic]
# libgsm1/focal,now 1.0.18-2 amd64 [installed,automatic]
# libgssapi-krb5-2/focal-updates,focal-security,now 1.17-6ubuntu4.3 amd64 [installed,automatic]
# libgssapi3-heimdal/now 7.7.0+dfsg-1ubuntu1.3 amd64 [installed,upgradable to: 7.7.0+dfsg-1ubuntu1.4]
# libgssrpc4/focal-updates,focal-security,now 1.17-6ubuntu4.3 amd64 [installed,automatic]
# libgstreamer-plugins-base1.0-0/focal-updates,focal-security,now 1.16.3-0ubuntu1.1 amd64 [installed,automatic]
# libgstreamer1.0-0/focal-updates,focal-security,now 1.16.3-0ubuntu1.1 amd64 [installed,automatic]
# libgtk-3-0/focal-updates,now 3.24.20-0ubuntu1.1 amd64 [installed,automatic]
# libgtk-3-common/focal-updates,now 3.24.20-0ubuntu1.1 all [installed,automatic]
# libgts-0.7-5/focal,now 0.7.6+darcs121130-4 amd64 [installed,automatic]
# libgudev-1.0-0/focal,now 1:233-1 amd64 [installed,automatic]
# libgvc6/focal,now 2.42.2-3build2 amd64 [installed,automatic]
# libgvpr2/focal,now 2.42.2-3build2 amd64 [installed,automatic]
# libharfbuzz0b/focal-updates,focal-security,now 2.6.4-1ubuntu4.2 amd64 [installed,automatic]
# libhcrypto4-heimdal/now 7.7.0+dfsg-1ubuntu1.3 amd64 [installed,upgradable to: 7.7.0+dfsg-1ubuntu1.4]
# libhdf4-0-alt/focal,now 4.2.14-1ubuntu1 amd64 [installed,automatic]
# libhdf4-alt-dev/focal,now 4.2.14-1ubuntu1 amd64 [installed,automatic]
# libhdf5-103/focal,now 1.10.4+repack-11ubuntu1 amd64 [installed,automatic]
# libhdf5-cpp-103/focal,now 1.10.4+repack-11ubuntu1 amd64 [installed,automatic]
# libhdf5-dev/focal,now 1.10.4+repack-11ubuntu1 amd64 [installed]
# libhdf5-openmpi-103/focal,now 1.10.4+repack-11ubuntu1 amd64 [installed,automatic]
# libheif-dev/focal,now 1.6.1-1build1 amd64 [installed,automatic]
# libheif1/focal,now 1.6.1-1build1 amd64 [installed,automatic]
# libheimbase1-heimdal/now 7.7.0+dfsg-1ubuntu1.3 amd64 [installed,upgradable to: 7.7.0+dfsg-1ubuntu1.4]
# libheimntlm0-heimdal/now 7.7.0+dfsg-1ubuntu1.3 amd64 [installed,upgradable to: 7.7.0+dfsg-1ubuntu1.4]
# libhogweed5/focal-updates,focal-security,now 3.5.1+really3.5.1-2ubuntu0.2 amd64 [installed]
# libhttp-parser-dev/focal,now 2.9.2-2 amd64 [installed,automatic]
# libhttp-parser2.9/focal,now 2.9.2-2 amd64 [installed,automatic]
# libhwloc-dev/focal,now 2.1.0+dfsg-4 amd64 [installed,automatic]
# libhwloc-plugins/focal,now 2.1.0+dfsg-4 amd64 [installed,automatic]
# libhwloc15/focal,now 2.1.0+dfsg-4 amd64 [installed,automatic]
# libhx509-5-heimdal/now 7.7.0+dfsg-1ubuntu1.3 amd64 [installed,upgradable to: 7.7.0+dfsg-1ubuntu1.4]
# libibverbs-dev/focal,now 28.0-1ubuntu1 amd64 [installed,automatic]
# libibverbs1/focal,now 28.0-1ubuntu1 amd64 [installed,automatic]
# libice-dev/focal,now 2:1.0.10-0ubuntu1 amd64 [installed,automatic]
# libice6/focal,now 2:1.0.10-0ubuntu1 amd64 [installed,automatic]
# libicu-dev/focal-updates,focal-security,now 66.1-2ubuntu2.1 amd64 [installed]
# libicu66/focal-updates,focal-security,now 66.1-2ubuntu2.1 amd64 [installed,automatic]
# libidn2-0/focal,now 2.2.0-2 amd64 [installed]
# libiec61883-0/focal,now 1.2.0-3 amd64 [installed,automatic]
# libilmbase-dev/focal,now 2.3.0-6build1 amd64 [installed,automatic]
# libilmbase24/focal,now 2.3.0-6build1 amd64 [installed,automatic]
# libinput-bin/focal-updates,focal-security,now 1.15.5-1ubuntu0.3 amd64 [installed,automatic]
# libinput10/focal-updates,focal-security,now 1.15.5-1ubuntu0.3 amd64 [installed,automatic]
# libio-pty-perl/focal,now 1:1.12-1 amd64 [installed,automatic]
# libip4tc2/focal-updates,now 1.8.4-3ubuntu2.1 amd64 [installed,automatic]
# libipc-run-perl/focal,now 20180523.0-2 all [installed,automatic]
# libisl22/focal,now 0.22.1-1 amd64 [installed,automatic]
# libitm1/focal-updates,focal-security,now 10.3.0-1ubuntu1~20.04 amd64 [installed,automatic]
# libjack-dev/focal,now 1:0.125.0-3build2 amd64 [installed]
# libjack0/focal,now 1:0.125.0-3build2 amd64 [installed,automatic]
# libjbig-dev/focal-updates,focal-security,now 2.1-3.1ubuntu0.20.04.1 amd64 [installed,automatic]
# libjbig0/focal-updates,focal-security,now 2.1-3.1ubuntu0.20.04.1 amd64 [installed,automatic]
# libjpeg-dev/focal,now 8c-2ubuntu8 amd64 [installed,automatic]
# libjpeg-turbo8-dev/focal-updates,focal-security,now 2.0.3-0ubuntu1.20.04.3 amd64 [installed,automatic]
# libjpeg-turbo8/focal-updates,focal-security,now 2.0.3-0ubuntu1.20.04.3 amd64 [installed,automatic]
# libjpeg8-dev/focal,now 8c-2ubuntu8 amd64 [installed,automatic]
# libjpeg8/focal,now 8c-2ubuntu8 amd64 [installed,automatic]
# libjson-c-dev/focal-updates,focal-security,now 0.13.1+dfsg-7ubuntu0.3 amd64 [installed,automatic]
# libjson-c4/focal-updates,focal-security,now 0.13.1+dfsg-7ubuntu0.3 amd64 [installed,automatic]
# libjson-glib-1.0-0/focal,now 1.4.4-2ubuntu2 amd64 [installed,automatic]
# libjson-glib-1.0-common/focal,now 1.4.4-2ubuntu2 all [installed,automatic]
# libjsoncpp1/focal,now 1.7.4-3.1ubuntu2 amd64 [installed,automatic]
# libk5crypto3/focal-updates,focal-security,now 1.17-6ubuntu4.3 amd64 [installed,automatic]
# libkadm5clnt-mit11/focal-updates,focal-security,now 1.17-6ubuntu4.3 amd64 [installed,automatic]
# libkadm5srv-mit11/focal-updates,focal-security,now 1.17-6ubuntu4.3 amd64 [installed,automatic]
# libkdb5-9/focal-updates,focal-security,now 1.17-6ubuntu4.3 amd64 [installed,automatic]
# libkeyutils1/focal-updates,now 1.6-6ubuntu1.1 amd64 [installed,automatic]
# libkml-dev/focal,now 1.3.0-8build1 amd64 [installed,automatic]
# libkmlbase1/focal,now 1.3.0-8build1 amd64 [installed,automatic]
# libkmlconvenience1/focal,now 1.3.0-8build1 amd64 [installed,automatic]
# libkmldom1/focal,now 1.3.0-8build1 amd64 [installed,automatic]
# libkmlengine1/focal,now 1.3.0-8build1 amd64 [installed,automatic]
# libkmlregionator1/focal,now 1.3.0-8build1 amd64 [installed,automatic]
# libkmlxsd1/focal,now 1.3.0-8build1 amd64 [installed,automatic]
# libkmod2/focal-updates,now 27-1ubuntu2.1 amd64 [installed,automatic]
# libkrb5-26-heimdal/now 7.7.0+dfsg-1ubuntu1.3 amd64 [installed,upgradable to: 7.7.0+dfsg-1ubuntu1.4]
# libkrb5-3/focal-updates,focal-security,now 1.17-6ubuntu4.3 amd64 [installed,automatic]
# libkrb5-dev/focal-updates,focal-security,now 1.17-6ubuntu4.3 amd64 [installed,automatic]
# libkrb5support0/focal-updates,focal-security,now 1.17-6ubuntu4.3 amd64 [installed,automatic]
# libksba8/focal-updates,focal-security,now 1.3.5-2ubuntu0.20.04.2 amd64 [installed,automatic]
# liblab-gamut1/focal,now 2.42.2-3build2 amd64 [installed,automatic]
# liblapack-dev/focal,now 3.9.0-1build1 amd64 [installed]
# liblapack3/focal,now 3.9.0-1build1 amd64 [installed,automatic]
# liblcms2-2/focal,now 2.9-4 amd64 [installed,automatic]
# libldap-2.4-2/focal-updates,focal-security,now 2.4.49+dfsg-2ubuntu1.9 amd64 [installed,automatic]
# libldap-common/focal-updates,focal-security,now 2.4.49+dfsg-2ubuntu1.9 all [installed,automatic]
# liblept5/focal,now 1.79.0-1 amd64 [installed,automatic]
# liblilv-0-0/focal-updates,now 0.24.6-1ubuntu0.1 amd64 [installed,automatic]
# libllvm10/focal,now 1:10.0.0-4ubuntu1 amd64 [installed,automatic]
# libllvm12/focal-updates,focal-security,now 1:12.0.0-3ubuntu1~20.04.5 amd64 [installed,automatic]
# liblmdb0/focal,now 0.9.24-1 amd64 [installed,automatic]
# liblsan0/focal-updates,focal-security,now 10.3.0-1ubuntu1~20.04 amd64 [installed,automatic]
# libltdl-dev/focal,now 2.4.6-14 amd64 [installed,automatic]
# libltdl7/focal,now 2.4.6-14 amd64 [installed,automatic]
# liblz4-1/focal-updates,focal-security,now 1.9.2-2ubuntu0.20.04.1 amd64 [installed]
# liblzma-dev/focal-updates,focal-security,now 5.2.4-1ubuntu1.1 amd64 [installed,automatic]
# liblzma5/focal-updates,focal-security,now 5.2.4-1ubuntu1.1 amd64 [installed]
# libmagic-mgc/focal,now 1:5.38-4 amd64 [installed,automatic]
# libmagic1/focal,now 1:5.38-4 amd64 [installed,automatic]
# libmbedcrypto3/focal,now 2.16.4-1ubuntu2 amd64 [installed,automatic]
# libmbedtls-dev/focal,now 2.16.4-1ubuntu2 amd64 [installed,automatic]
# libmbedtls12/focal,now 2.16.4-1ubuntu2 amd64 [installed,automatic]
# libmbedx509-0/focal,now 2.16.4-1ubuntu2 amd64 [installed,automatic]
# libminizip-dev/focal,now 1.1-8build1 amd64 [installed,automatic]
# libminizip1/focal,now 1.1-8build1 amd64 [installed,automatic]
# libmnl0/focal,now 1.0.4-2 amd64 [installed,automatic]
# libmount1/focal-updates,focal-security,now 2.34-0.1ubuntu9.3 amd64 [installed]
# libmp3lame0/focal,now 3.100-3 amd64 [installed,automatic]
# libmpc3/focal,now 1.1.0-1 amd64 [installed,automatic]
# libmpdec2/focal,now 2.4.2-3 amd64 [installed,automatic]
# libmpfr6/focal,now 4.0.2-1 amd64 [installed,automatic]
# libmpg123-0/focal,now 1.25.13-1 amd64 [installed,automatic]
# libmtdev1/focal,now 1.1.5-1.1 amd64 [installed,automatic]
# libmysofa1/focal,now 1.0~dfsg0-1 amd64 [installed,automatic]
# libmysqlclient-dev/focal-updates,focal-security,now 8.0.33-0ubuntu0.20.04.2 amd64 [installed,automatic]
# libmysqlclient21/focal-updates,focal-security,now 8.0.33-0ubuntu0.20.04.2 amd64 [installed,automatic]
# libnccl-dev/unknown,now 2.16.2-1+cuda11.8 amd64 [installed,upgradable to: 2.18.1-1+cuda12.1]
# libnccl2/unknown,now 2.16.2-1+cuda11.8 amd64 [installed,upgradable to: 2.18.1-1+cuda12.1]
# libncurses-dev/focal-updates,focal-security,now 6.2-0ubuntu2.1 amd64 [installed,automatic]
# libncurses5-dev/focal-updates,focal-security,now 6.2-0ubuntu2.1 amd64 [installed]
# libncurses6/focal-updates,focal-security,now 6.2-0ubuntu2.1 amd64 [installed]
# libncursesw5/focal,now 6.2-0ubuntu2 amd64 [installed,upgradable to: 6.2-0ubuntu2.1]
# libncursesw6/focal-updates,focal-security,now 6.2-0ubuntu2.1 amd64 [installed]
# libnetcdf-c++4/focal,now 4.2-11build2 amd64 [installed,automatic]
# libnetcdf-dev/focal,now 1:4.7.3-1 amd64 [installed,automatic]
# libnetcdf15/focal,now 1:4.7.3-1 amd64 [installed,automatic]
# libnettle7/focal-updates,focal-security,now 3.5.1+really3.5.1-2ubuntu0.2 amd64 [installed]
# libnghttp2-14/focal-updates,focal-security,now 1.40.0-1ubuntu0.1 amd64 [installed,automatic]
# libnl-3-200/focal-updates,now 3.4.0-1ubuntu0.1 amd64 [installed,automatic]
# libnl-3-dev/focal-updates,now 3.4.0-1ubuntu0.1 amd64 [installed,automatic]
# libnl-route-3-200/focal-updates,now 3.4.0-1ubuntu0.1 amd64 [installed,automatic]
# libnl-route-3-dev/focal-updates,now 3.4.0-1ubuntu0.1 amd64 [installed,automatic]
# libnorm-dev/focal,now 1.5.8+dfsg2-2build1 amd64 [installed,automatic]
# libnorm1/focal,now 1.5.8+dfsg2-2build1 amd64 [installed,automatic]
# libnpp-11-8/unknown,now 11.8.0.86-1 amd64 [installed]
# libnpp-dev-11-8/unknown,now 11.8.0.86-1 amd64 [installed]
# libnpth0/focal,now 1.6-1 amd64 [installed,automatic]
# libnspr4/focal,now 2:4.25-1 amd64 [installed,automatic]
# libnss3/focal-updates,focal-security,now 2:3.49.1-1ubuntu1.9 amd64 [installed,automatic]
# libnuma-dev/focal,now 2.0.12-1 amd64 [installed,automatic]
# libnuma1/focal,now 2.0.12-1 amd64 [installed,automatic]
# libnvjpeg-11-8/unknown,now 11.9.0.86-1 amd64 [installed,automatic]
# libnvjpeg-dev-11-8/unknown,now 11.9.0.86-1 amd64 [installed,automatic]
# libobjc-9-dev/focal-updates,focal-security,now 9.4.0-1ubuntu1~20.04.1 amd64 [installed,automatic]
# libobjc4/focal-updates,focal-security,now 10.3.0-1ubuntu1~20.04 amd64 [installed,automatic]
# libodbc1/focal,now 2.3.6-0.1build1 amd64 [installed,automatic]
# libogdi-dev/focal,now 4.1.0+ds-1build1 amd64 [installed,automatic]
# libogdi4.1/focal,now 4.1.0+ds-1build1 amd64 [installed,automatic]
# libogg-dev/focal,now 1.3.4-0ubuntu1 amd64 [installed,automatic]
# libogg0/focal,now 1.3.4-0ubuntu1 amd64 [installed,automatic]
# libopenal-data/focal,now 1:1.19.1-1 all [installed,automatic]
# libopenal1/focal,now 1:1.19.1-1 amd64 [installed,automatic]
# libopenblas-dev/focal-updates,now 0.3.8+ds-1ubuntu0.20.04.1 amd64 [installed]
# libopenblas-pthread-dev/focal-updates,now 0.3.8+ds-1ubuntu0.20.04.1 amd64 [installed,automatic]
# libopenblas0-pthread/focal-updates,now 0.3.8+ds-1ubuntu0.20.04.1 amd64 [installed,automatic]
# libopenblas0/focal-updates,now 0.3.8+ds-1ubuntu0.20.04.1 amd64 [installed,automatic]
# libopencv-calib3d-dev/focal,now 4.2.0+dfsg-5+focal2 amd64 [installed,automatic]
# libopencv-calib3d4.2/focal,now 4.2.0+dfsg-5+focal2 amd64 [installed,automatic]
# libopencv-contrib-dev/focal,now 4.2.0+dfsg-5+focal2 amd64 [installed,automatic]
# libopencv-contrib4.2/focal,now 4.2.0+dfsg-5+focal2 amd64 [installed,automatic]
# libopencv-core-dev/focal,now 4.2.0+dfsg-5+focal2 amd64 [installed,automatic]
# libopencv-core4.2/focal,now 4.2.0+dfsg-5+focal2 amd64 [installed,automatic]
# libopencv-dev/focal,now 4.2.0+dfsg-5+focal2 amd64 [installed]
# libopencv-dnn-dev/focal,now 4.2.0+dfsg-5+focal2 amd64 [installed,automatic]
# libopencv-dnn4.2/focal,now 4.2.0+dfsg-5+focal2 amd64 [installed,automatic]
# libopencv-features2d-dev/focal,now 4.2.0+dfsg-5+focal2 amd64 [installed,automatic]
# libopencv-features2d4.2/focal,now 4.2.0+dfsg-5+focal2 amd64 [installed,automatic]
# libopencv-flann-dev/focal,now 4.2.0+dfsg-5+focal2 amd64 [installed,automatic]
# libopencv-flann4.2/focal,now 4.2.0+dfsg-5+focal2 amd64 [installed,automatic]
# libopencv-highgui-dev/focal,now 4.2.0+dfsg-5+focal2 amd64 [installed,automatic]
# libopencv-highgui4.2/focal,now 4.2.0+dfsg-5+focal2 amd64 [installed,automatic]
# libopencv-imgcodecs-dev/focal,now 4.2.0+dfsg-5+focal2 amd64 [installed,automatic]
# libopencv-imgcodecs4.2/focal,now 4.2.0+dfsg-5+focal2 amd64 [installed,automatic]
# libopencv-imgproc-dev/focal,now 4.2.0+dfsg-5+focal2 amd64 [installed,automatic]
# libopencv-imgproc4.2/focal,now 4.2.0+dfsg-5+focal2 amd64 [installed,automatic]
# libopencv-ml-dev/focal,now 4.2.0+dfsg-5+focal2 amd64 [installed,automatic]
# libopencv-ml4.2/focal,now 4.2.0+dfsg-5+focal2 amd64 [installed,automatic]
# libopencv-objdetect-dev/focal,now 4.2.0+dfsg-5+focal2 amd64 [installed,automatic]
# libopencv-objdetect4.2/focal,now 4.2.0+dfsg-5+focal2 amd64 [installed,automatic]
# libopencv-photo-dev/focal,now 4.2.0+dfsg-5+focal2 amd64 [installed,automatic]
# libopencv-photo4.2/focal,now 4.2.0+dfsg-5+focal2 amd64 [installed,automatic]
# libopencv-shape-dev/focal,now 4.2.0+dfsg-5+focal2 amd64 [installed,automatic]
# libopencv-shape4.2/focal,now 4.2.0+dfsg-5+focal2 amd64 [installed,automatic]
# libopencv-stitching-dev/focal,now 4.2.0+dfsg-5+focal2 amd64 [installed,automatic]
# libopencv-stitching4.2/focal,now 4.2.0+dfsg-5+focal2 amd64 [installed,automatic]
# libopencv-superres-dev/focal,now 4.2.0+dfsg-5+focal2 amd64 [installed,automatic]
# libopencv-superres4.2/focal,now 4.2.0+dfsg-5+focal2 amd64 [installed,automatic]
# libopencv-ts-dev/focal,now 4.2.0+dfsg-5+focal2 amd64 [installed,automatic]
# libopencv-video-dev/focal,now 4.2.0+dfsg-5+focal2 amd64 [installed,automatic]
# libopencv-video4.2/focal,now 4.2.0+dfsg-5+focal2 amd64 [installed,automatic]
# libopencv-videoio-dev/focal,now 4.2.0+dfsg-5+focal2 amd64 [installed,automatic]
# libopencv-videoio4.2/focal,now 4.2.0+dfsg-5+focal2 amd64 [installed,automatic]
# libopencv-videostab-dev/focal,now 4.2.0+dfsg-5+focal2 amd64 [installed,automatic]
# libopencv-videostab4.2/focal,now 4.2.0+dfsg-5+focal2 amd64 [installed,automatic]
# libopencv-viz-dev/focal,now 4.2.0+dfsg-5+focal2 amd64 [installed,automatic]
# libopencv-viz4.2/focal,now 4.2.0+dfsg-5+focal2 amd64 [installed,automatic]
# ...
# python3-lib2to3/focal-updates,focal-security,now 3.8.10-0ubuntu1~20.04 all [installed,automatic]
# python3-minimal/focal,now 3.8.2-0ubuntu2 amd64 [installed,automatic]
# python3-pkg-resources/focal-updates,focal-security,now 45.2.0-1ubuntu0.1 all [installed,automatic]
# python3-requests-unixsocket/focal,now 0.2.0-2 all [installed,automatic]
# python3-requests/focal,now 2.22.0-2ubuntu1 all [installed,automatic]
# python3-six/focal,now 1.14.0-2 all [installed,automatic]
# python3-software-properties/focal-updates,now 0.99.9.11 all [installed,automatic]
# python3-urllib3/focal-updates,focal-security,now 1.25.8-2ubuntu0.2 all [installed,automatic]
# python3.10-dev/focal,now 3.10.12-1+focal1 amd64 [installed]
# python3.10-distutils/focal,now 3.10.12-1+focal1 all [installed]
# python3.10-lib2to3/focal,now 3.10.12-1+focal1 all [installed,automatic]
# python3.10-minimal/focal,now 3.10.12-1+focal1 amd64 [installed,automatic]
# python3.10-tk/focal,now 3.10.12-1+focal1 amd64 [installed]
# python3.10/focal,now 3.10.12-1+focal1 amd64 [installed]
# python3.8-dev/focal-updates,focal-security,now 3.8.10-0ubuntu1~20.04.8 amd64 [installed,automatic]
# python3.8-minimal/focal-updates,focal-security,now 3.8.10-0ubuntu1~20.04.8 amd64 [installed,automatic]
# python3.8/focal-updates,focal-security,now 3.8.10-0ubuntu1~20.04.8 amd64 [installed,automatic]
# python3/focal,now 3.8.2-0ubuntu2 amd64 [installed,automatic]
# qt5-default/focal-updates,focal-security,now 5.12.8+dfsg-0ubuntu2.1 amd64 [installed]
# qt5-qmake-bin/focal-updates,focal-security,now 5.12.8+dfsg-0ubuntu2.1 amd64 [installed,automatic]
# qt5-qmake/focal-updates,focal-security,now 5.12.8+dfsg-0ubuntu2.1 amd64 [installed,automatic]
# qtbase5-dev-tools/focal-updates,focal-security,now 5.12.8+dfsg-0ubuntu2.1 amd64 [installed,automatic]
# qtbase5-dev/focal-updates,focal-security,now 5.12.8+dfsg-0ubuntu2.1 amd64 [installed,automatic]
# qtchooser/focal,now 66-2build1 amd64 [installed,automatic]
# r-base-core/focal-cran40,now 4.3.0-1.2004.0 amd64 [installed]
# r-base-dev/focal-cran40,now 4.3.0-1.2004.0 all [installed]
# r-base/focal-cran40,now 4.3.0-1.2004.0 all [installed]
# r-cran-askpass/focal,now 1.1-1.1~ubuntu20.04.1~ppa1 amd64 [installed,automatic]
# r-cran-backports/focal,now 1.4.1-1cran1.2004.0 amd64 [installed,automatic]
# r-cran-base64enc/focal,now 0.1-3-2.1.1.1~ubuntu20.04.1~ppa1 amd64 [installed,automatic]
# r-cran-bit64/focal,now 4.0.5-1cran1.2004.0 amd64 [installed,automatic]
# r-cran-bit/focal,now 4.0.4-1cran1.2004.0 amd64 [installed,automatic]
# r-cran-blob/focal,now 1.2.4-1cran1.2004.0 all [installed,automatic]
# r-cran-boot/focal-cran40,now 1.3-28-1cran1.2004.0 all [installed,automatic]
# r-cran-brew/focal,now 1.0-8-1cran1.2004.0 all [installed,automatic]
# r-cran-brio/focal,now 1.1.3-1cran1.2004.0 amd64 [installed,automatic]
# r-cran-broom/focal,now 1.0.4-1cran1.2004.0 all [installed,automatic]
# r-cran-bslib/focal,now 0.4.1-1cran1.2004.0 all [installed,automatic]
# r-cran-cachem/focal,now 1.0.8-1cran1.2004.0 amd64 [installed,automatic]
# r-cran-callr/focal,now 3.7.3-1cran1.2004.0 all [installed,automatic]
# r-cran-cellranger/focal,now 1.1.0-2.1~ubuntu20.04.1~ppa1 all [installed,automatic]
# r-cran-class/focal,now 7.3-22-1cran1.2004.0 amd64 [installed,automatic]
# r-cran-cli/focal,now 3.6.1-1cran1.2004.0 amd64 [installed,automatic]
# r-cran-clipr/focal,now 0.8.0-1cran1.2004.0 all [installed,automatic]
# r-cran-cluster/focal-cran40,now 2.1.4-1.2004.0 amd64 [installed,automatic]
# r-cran-codetools/focal-cran40,now 0.2-19-1cran1.2004.0 all [installed,automatic]
# r-cran-colorspace/focal,now 2.1-0-1cran1.2004.0 amd64 [installed,automatic]
# r-cran-commonmark/focal,now 1.9.0-1cran1.2004.0 amd64 [installed,automatic]
# r-cran-cpp11/focal,now 0.4.3-1cran1.2004.0 all [installed,automatic]
# r-cran-crayon/focal,now 1.5.2-1cran1.2004.0 all [installed,automatic]
# r-cran-credentials/focal,now 1.3.2-1cran1.2004.0 all [installed,automatic]
# r-cran-curl/focal,now 5.0.0-1cran1.2004.0 amd64 [installed,automatic]
# r-cran-data.table/focal,now 1.14.8-1cran1.2004.0 amd64 [installed,automatic]
# r-cran-dbi/focal,now 1.1.3-1cran1.2004.0 all [installed,automatic]
# r-cran-dbplyr/focal,now 2.3.2-1cran1.2004.0 all [installed,automatic]
# r-cran-desc/focal,now 1.4.2-1cran1.2004.0 all [installed,automatic]
# r-cran-devtools/focal,now 2.4.3-1cran1.2004.0 all [installed]
# r-cran-diffobj/focal,now 0.3.5-1cran1.2004.0 amd64 [installed,automatic]
# r-cran-digest/focal,now 0.6.30-1cran1.2004.0 amd64 [installed,automatic]
# r-cran-dplyr/focal,now 1.1.2-1cran1.2004.0 amd64 [installed,automatic]
# r-cran-dtplyr/focal,now 1.3.1-1cran1.2004.0 all [installed,automatic]
# r-cran-ellipsis/focal,now 0.3.2-1cran1.2004.0 amd64 [installed,automatic]
# r-cran-evaluate/focal,now 0.21-1cran1.2004.0 all [installed,automatic]
# r-cran-fansi/focal,now 1.0.4-1cran1.2004.0 amd64 [installed,automatic]
# r-cran-farver/focal,now 2.1.1-1cran1.2004.0 amd64 [installed,automatic]
# r-cran-fastmap/focal,now 1.1.1-1cran1.2004.0 amd64 [installed,automatic]
# r-cran-fontawesome/focal,now 0.5.1-1cran1.2004.0 all [installed,automatic]
# r-cran-forcats/focal,now 1.0.0-1cran1.2004.0 all [installed,automatic]
# r-cran-foreign/focal-cran40,now 0.8.82-1.2004.0 amd64 [installed,automatic]
# r-cran-fs/focal,now 1.6.2-1cran1.2004.0 amd64 [installed,automatic]
# r-cran-gargle/focal,now 1.4.0-1cran1.2004.0 all [installed,automatic]
# r-cran-generics/focal,now 0.1.3-1cran1.2004.0 all [installed,automatic]
# r-cran-gert/focal,now 1.9.1-1cran1.2004.0 amd64 [installed,automatic]
# r-cran-ggplot2/focal,now 3.4.2-1cran1.2004.0 all [installed,automatic]
# r-cran-gh/focal,now 1.4.0-1cran1.2004.0 all [installed,automatic]
# r-cran-gitcreds/focal,now 0.1.2-1cran1.2004.0 all [installed,automatic]
# r-cran-glue/focal,now 1.6.2-1cran1.2004.0 amd64 [installed,automatic]
# r-cran-googledrive/focal,now 2.1.0-1cran1.2004.0 all [installed,automatic]
# r-cran-googlesheets4/focal,now 1.1.0-1cran1.2004.0 all [installed,automatic]
# r-cran-gtable/focal,now 0.3.3-1cran1.2004.0 all [installed,automatic]
# r-cran-haven/focal,now 2.5.2-1cran1.2004.0 amd64 [installed,automatic]
# r-cran-highr/focal,now 0.9-1cran1.2004.0 all [installed,automatic]
# r-cran-hms/focal,now 1.1.3-1cran1.2004.0 all [installed,automatic]
# r-cran-htmltools/focal,now 0.5.5-1cran1.2004.0 amd64 [installed,automatic]
# r-cran-httr2/focal,now 0.2.3-1cran1.2004.0 all [installed,automatic]
# r-cran-httr/focal,now 1.4.6-1cran1.2004.0 all [installed,automatic]
# r-cran-ids/focal,now 1.0.1-1cran1.2004.0 all [installed,automatic]
# r-cran-ini/focal,now 0.3.1-1.1~ubuntu20.04.1~ppa1 all [installed,automatic]
# r-cran-isoband/focal,now 0.2.6-1cran1.2004.0 amd64 [installed,automatic]
# r-cran-jquerylib/focal,now 0.1.4-1cran1.2004.0 all [installed,automatic]
# r-cran-jsonlite/focal,now 1.8.3-1cran1.2004.0 amd64 [installed,automatic]
# r-cran-kernsmooth/focal,now 2.23-21-1cran1.2004.0 amd64 [installed,automatic]
# r-cran-knitr/focal,now 1.43-1cran1.2004.0 all [installed,automatic]
# r-cran-labeling/focal,now 0.4.2-1cran1.2004.0 all [installed,automatic]
# r-cran-lattice/focal-cran40,now 0.21-8-1cran1.2004.0 amd64 [installed,automatic]
# r-cran-lifecycle/focal,now 1.0.3-1cran1.2004.0 all [installed,automatic]
# r-cran-lubridate/focal,now 1.9.2-1cran1.2004.0 amd64 [installed,automatic]
# r-cran-magrittr/focal,now 2.0.3-1cran1.2004.0 amd64 [installed,automatic]
# r-cran-mass/focal,now 7.3-60-1cran1.2004.0 amd64 [installed,automatic]
# r-cran-matrix/focal-cran40,now 1.5-4.1-1.2004.0 amd64 [installed,automatic]
# r-cran-memoise/focal,now 2.0.1-1cran1.2004.0 all [installed,automatic]
# r-cran-mgcv/focal-cran40,now 1.8-42-1cran1.2004.0 amd64 [installed,automatic]
# r-cran-mime/focal,now 0.12-1cran1.2004.0 amd64 [installed,automatic]
# r-cran-modelr/focal,now 0.1.11-1cran1.2004.0 all [installed,automatic]
# r-cran-munsell/focal,now 0.5.0-1.1~ubuntu20.04.1~ppa1 all [installed,automatic]
# r-cran-nlme/focal-cran40,now 3.1.162-1.2004.0 amd64 [installed,automatic]
# r-cran-nnet/focal,now 7.3-19-1cran1.2004.0 amd64 [installed,automatic]
# r-cran-openssl/focal,now 2.0.6-1cran1.2004.0 amd64 [installed,automatic]
# r-cran-pillar/focal,now 1.9.0-1cran1.2004.0 all [installed,automatic]
# r-cran-pkgbuild/focal,now 1.4.0-1cran1.2004.0 all [installed,automatic]
# r-cran-pkgconfig/focal,now 2.0.3-1.1~ubuntu20.04.1~ppa1 all [installed,automatic]
# r-cran-pkgload/focal,now 1.3.1-1cran1.2004.0 all [installed,automatic]
# r-cran-praise/focal,now 1.0.0-3.1~ubuntu20.04.1~ppa1 all [installed,automatic]
# r-cran-prettyunits/focal,now 1.1.1-1.1~ubuntu20.04.1~ppa1 all [installed,automatic]
# r-cran-processx/focal,now 3.8.1-1cran1.2004.0 amd64 [installed,automatic]
# r-cran-progress/focal,now 1.2.2-1.1~ubuntu20.04.1~ppa1 all [installed,automatic]
# r-cran-ps/focal,now 1.7.5-1cran1.2004.0 amd64 [installed,automatic]
# r-cran-purrr/focal,now 1.0.1-1cran1.2004.0 amd64 [installed,automatic]
# r-cran-r6/focal,now 2.5.1-1cran1.2004.0 all [installed,automatic]
# r-cran-rappdirs/focal,now 0.3.3-1cran1.2004.0 amd64 [installed,automatic]
# r-cran-rcmdcheck/focal,now 1.4.0-1cran1.2004.0 all [installed,automatic]
# r-cran-rcolorbrewer/focal,now 1.1-3-1cran1.2004.0 all [installed,automatic]
# r-cran-readr/focal,now 2.1.4-1cran1.2004.0 amd64 [installed,automatic]
# r-cran-readxl/focal,now 1.4.2-1cran1.2004.0 amd64 [installed,automatic]
# r-cran-rematch2/focal,now 2.1.2-1cran1.2004.0 all [installed,automatic]
# r-cran-rematch/focal,now 1.0.1-2.1~ubuntu20.04.1~ppa1 all [installed,automatic]
# r-cran-remotes/focal,now 2.4.2-1cran1.2004.0 all [installed,automatic]
# r-cran-reprex/focal,now 2.0.2-1cran1.2004.0 all [installed,automatic]
# r-cran-rlang/focal,now 1.1.1-1cran1.2004.0 amd64 [installed,automatic]
# r-cran-rmarkdown/focal,now 2.22-1cran1.2004.0 all [installed,automatic]
# r-cran-roxygen2/focal,now 7.2.2-1cran1.2004.0 amd64 [installed,automatic]
# r-cran-rpart/focal-cran40,now 4.1.19-1.2004.0 amd64 [installed,automatic]
# r-cran-rprojroot/focal,now 2.0.3-1cran1.2004.0 all [installed,automatic]
# r-cran-rstudioapi/focal,now 0.14-1cran1.2004.0 all [installed,automatic]
# r-cran-rversions/focal,now 2.1.2-1cran1.2004.0 all [installed,automatic]
# r-cran-rvest/focal,now 1.0.3-1cran1.2004.0 all [installed,automatic]
# r-cran-sass/focal,now 0.4.6-1cran1.2004.0 amd64 [installed,automatic]
# r-cran-scales/focal,now 1.2.1-1cran1.2004.0 all [installed,automatic]
# r-cran-selectr/focal,now 0.4-2-1.1~ubuntu20.04.1~ppa1 all [installed,automatic]
# r-cran-sessioninfo/focal,now 1.2.2-1cran1.2004.0 all [installed,automatic]
# r-cran-spatial/focal,now 7.3-16-1cran1.2004.0 amd64 [installed,automatic]
# r-cran-stringi/focal,now 1.7.12-1cran1.2004.0 amd64 [installed,automatic]
# r-cran-stringr/focal,now 1.5.0-1cran1.2004.0 all [installed,automatic]
# r-cran-survival/focal-cran40,now 3.5-5-1cran1.2004.0 amd64 [installed,automatic]
# r-cran-svglite/focal,now 2.1.1-1cran1.2004.0 amd64 [installed,automatic]
# r-cran-sys/focal,now 3.4.2-1cran1.2004.0 amd64 [installed,automatic]
# r-cran-systemfonts/focal,now 1.0.4-1cran1.2004.0 amd64 [installed,automatic]
# r-cran-testthat/focal,now 3.1.8-1cran1.2004.0 amd64 [installed,automatic]
# r-cran-tibble/focal,now 3.2.1-1cran1.2004.0 amd64 [installed,automatic]
# r-cran-tidyr/focal,now 1.3.0-1cran1.2004.0 amd64 [installed,automatic]
# r-cran-tidyselect/focal,now 1.2.0-1cran1.2004.0 all [installed,automatic]
# r-cran-tidyverse/focal,now 1.3.1-1cran1.2004.0 all [installed]
# r-cran-timechange/focal,now 0.2.0-1cran1.2004.0 amd64 [installed,automatic]
# r-cran-tinytex/focal,now 0.45-1cran1.2004.0 all [installed,automatic]
# r-cran-tzdb/focal,now 0.4.0-1cran1.2004.0 amd64 [installed,automatic]
# r-cran-usethis/focal,now 2.1.6-1cran1.2004.0 all [installed,automatic]
# r-cran-utf8/focal,now 1.2.3-1cran1.2004.0 amd64 [installed,automatic]
# r-cran-uuid/focal,now 1.1-0-1cran1.2004.0 amd64 [installed,automatic]
# r-cran-vctrs/focal,now 0.6.2-1cran1.2004.0 amd64 [installed,automatic]
# r-cran-viridislite/focal,now 0.4.2-1cran1.2004.0 all [installed,automatic]
# r-cran-vroom/focal,now 1.6.3-1cran1.2004.0 amd64 [installed,automatic]
# r-cran-waldo/focal,now 0.5.1-1cran1.2004.0 all [installed,automatic]
# r-cran-whisker/focal,now 0.4-1.1~ubuntu20.04.1~ppa1 all [installed,automatic]
# r-cran-withr/focal,now 2.5.0-1cran1.2004.0 all [installed,automatic]
# r-cran-xfun/focal,now 0.39-1cran1.2004.0 amd64 [installed,automatic]
# r-cran-xml2/focal,now 1.3.4-1cran1.2004.0 amd64 [installed,automatic]
# r-cran-xopen/focal,now 1.0.0-1.1~ubuntu20.04.1~ppa1 all [installed,automatic]
# r-cran-yaml/focal,now 2.3.7-1cran1.2004.0 amd64 [installed,automatic]
# r-cran-zip/focal,now 2.3.0-1cran1.2004.0 amd64 [installed,automatic]
# r-recommended/focal-cran40,now 4.3.0-1.2004.0 all [installed,automatic]
# readline-common/focal,now 8.0-4 all [installed,automatic]
# rename/focal,now 1.10-1 all [installed]
# rsync/focal-updates,focal-security,now 3.1.3-8ubuntu0.5 amd64 [installed]
# sed/focal,now 4.7-1 amd64 [installed]
# sensible-utils/focal,now 0.0.12+nmu1 all [installed]
# shared-mime-info/focal,now 1.15-1 amd64 [installed,automatic]
# software-properties-common/focal-updates,now 0.99.9.11 all [installed]
# sound-theme-freedesktop/focal,now 0.8-2ubuntu1 all [installed,automatic]
# sudo/focal-updates,focal-security,now 1.8.31-1ubuntu1.5 amd64 [installed]
# systemd-sysv/focal-updates,now 245.4-4ubuntu3.21 amd64 [installed,automatic]
# systemd-timesyncd/focal-updates,now 245.4-4ubuntu3.21 amd64 [installed,automatic]
# systemd/focal-updates,now 245.4-4ubuntu3.21 amd64 [installed,automatic]
# sysvinit-utils/focal,now 2.96-2.1ubuntu1 amd64 [installed]
# tar/now 1.30+dfsg-7ubuntu0.20.04.2 amd64 [installed,upgradable to: 1.30+dfsg-7ubuntu0.20.04.3]
# tcl-dev/focal,now 8.6.9+1 amd64 [installed]
# tcl8.6-dev/focal,now 8.6.10+dfsg-1 amd64 [installed,automatic]
# tcl8.6/focal,now 8.6.10+dfsg-1 amd64 [installed,automatic]
# tcl/focal,now 8.6.9+1 amd64 [installed,automatic]
# tcllib/focal,now 1.20+dfsg-1 all [installed]
# tk-dev/focal,now 8.6.9+1 amd64 [installed]
# tk8.6-dev/focal,now 8.6.10-1 amd64 [installed,automatic]
# tk8.6/focal,now 8.6.10-1 amd64 [installed,automatic]
# tk/focal,now 8.6.9+1 amd64 [installed,automatic]
# tmux/focal-updates,focal-security,now 3.0a-2ubuntu0.4 amd64 [installed]
# tzdata/focal-updates,now 2023c-0ubuntu0.20.04.2 all [installed,automatic]
# ubuntu-keyring/focal-updates,now 2020.02.11.4 all [installed]
# ubuntu-mono/focal,now 19.04-0ubuntu3 all [installed,automatic]
# ucf/focal,now 3.0038+nmu1 all [installed,automatic]
# unixodbc-dev/focal,now 2.3.6-0.1build1 amd64 [installed,automatic]
# unrar/focal,now 1:5.6.6-2build1 amd64 [installed]
# unzip/focal-updates,focal-security,now 6.0-25ubuntu1.1 amd64 [installed]
# util-linux/focal-updates,focal-security,now 2.34-0.1ubuntu9.3 amd64 [installed]
# uuid-dev/focal-updates,focal-security,now 2.34-0.1ubuntu9.3 amd64 [installed,automatic]
# vim-common/focal-updates,focal-security,now 2:8.1.2269-1ubuntu5.14 all [installed,automatic]
# vim-runtime/focal-updates,focal-security,now 2:8.1.2269-1ubuntu5.14 all [installed,automatic]
# vim/focal-updates,focal-security,now 2:8.1.2269-1ubuntu5.14 amd64 [installed]
# wget/focal-updates,now 1.20.3-1ubuntu2 amd64 [installed]
# x11-common/focal,now 1:7.7+19ubuntu14 all [installed,automatic]
# x11proto-core-dev/focal,now 2019.2-1ubuntu1 all [installed,automatic]
# x11proto-dev/focal,now 2019.2-1ubuntu1 all [installed,automatic]
# x11proto-scrnsaver-dev/focal,now 2019.2-1ubuntu1 all [installed,automatic]
# x11proto-xext-dev/focal,now 2019.2-1ubuntu1 all [installed,automatic]
# xauth/focal,now 1:1.1-0ubuntu1 amd64 [installed,automatic]
# xdg-utils/focal-updates,focal-security,now 1.1.3-2ubuntu1.20.04.2 all [installed,automatic]
# xkb-data/focal,now 2.29-2 all [installed,automatic]
# xorg-sgml-doctools/focal,now 1:1.11-1 all [installed,automatic]
# xsel/focal,now 1.2.0+git9bfc13d.20180109-3 amd64 [installed,automatic]
# xtrans-dev/focal,now 1.4.0-1 all [installed,automatic]
# xxd/focal-updates,focal-security,now 2:8.1.2269-1ubuntu5.14 amd64 [installed,automatic]
# xz-utils/focal-updates,focal-security,now 5.2.4-1ubuntu1.1 amd64 [installed,automatic]
# zip/focal,now 3.0-11build1 amd64 [installed]
# zlib1g-dev/focal-updates,focal-security,now 1:1.2.11.dfsg-2ubuntu1.5 amd64 [installed,automatic]
# zlib1g/focal-updates,focal-security,now 1:1.2.11.dfsg-2ubuntu1.5 amd64 [installed]

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2022 NVIDIA Corporation
# Built on Wed_Sep_21_10:33:58_PDT_2022
# Cuda compilation tools, release 11.8, V11.8.89
# Build cuda_11.8.r11.8/compiler.31833905_0

# %%
code = """
// OpenMP program to print Hello World
// using C language

// OpenMP header
#include <omp.h>
#include <stdio.h>
#include <stdlib.h>

int main(int argc, char* argv[])
{

    // Beginning of parallel region
    #pragma omp parallel
    {
        printf("Hello World... from thread = %d \\n", omp_get_thread_num());
    }
    // Ending of parallel region
}
"""

# %%
code = """
// OpenMP program to print Hello World
// using C language

// OpenMP header

#include <omp.h>
#include <stdio.h>
#include <stdlib.h>

int main(int argc, char* argv[])
{

    #pragma omp parallel num_threads(4)
    {
      int id = omp_get_thread_num();
      int num_threads = omp_get_num_threads();

      if(id == 0){
        printf("Estou atrasada para a barreira ! Tecle enter \\n ");
        getchar();
      }
      #pragma omp barrier
        printf("Cheguei na barreira. Eu sou a %d de %d threads \\n", id, num_threads);
    }
    return 0;
}
"""

# %%
code = """
// OpenMP program to print Hello World
// using C language

// OpenMP header

#include <omp.h>
#include <stdio.h>
#include <stdlib.h>

int main(int argc, char* argv[])
{
  int a, i, n=5, b[n];
  #pragma omp parallel shared(a,b) private(i)
  {
    #pragma omp master
    {
      a = 10;
      printf("Construtor master é executado pela thread %d\\n", omp_get_thread_num());
    }
    #pragma omp barrier

    #pragma omp for
      for(i = 0; i < n; i++)
        b[i] = a;


  }
      printf("Apos a regiao paralela: \\n");
      for(i =0; i < n ; i++)
        printf("b[%d] = %d\\n", i, b[i]);
}
"""

# %%
#atomic

# %%
text_file = open("code.c", "w")
text_file.write(code)
text_file.close()

# %%
# Out:
# Overwriting code.c

# %%
#Useful
#gcc –g –fopenmp -o progT progT.c
#./progT

#gcc –g –fopenmp -o progT progT.c
#OMP_NUM_THREADS=6 ./progT

#omp_set_num_threads (4);

#gcc –o primos prog_omp_Numeros_Primos.c –fopenmp –O3 –std=c11 –lm
#./primos 5000000
####
# "-O3" is an optimization flag that instructs the compiler to perform aggressive code optimization at the highest level. This optimization level can improve the execution speed of the resulting program but may also increase the compilation time.
# "-std=c11" specifies the C programming language standard to be used during compilation. In this case, it indicates the C11 standard, which is the 2011 version of the C language standard.
# "-lm" is a linker flag that instructs the compiler to link the math library ("-l" indicates linking and "m" refers to the math library). This library provides mathematical functions like sqrt(), sin(), cos(), etc., that you can use in your C program.
####

#export OMP_NUM_THREADS = 16

# %%
#Hello World

# %%
# %%writefile code.c
# // OpenMP program to print Hello World
# // using C language
#
# // OpenMP header
# #include <omp.h>
# #include <stdio.h>
# #include <stdlib.h>
#
# int main(int argc, char* argv[])
# {
#
#     printf("Max Available Procs = %d\n", omp_get_num_procs());
#     printf("Max Available Threads = %d\n", omp_get_max_threads());
#     // Beginning of parallel region
#     #pragma omp parallel
#     {
#         printf("Hello World... from thread = %d \n", omp_get_thread_num());
#     }
#     // Ending of parallel region
# }
# Out:
# Overwriting code.c

# %%
# %%writefile code.c
#
# #include <omp.h>
# #include <stdio.h>
# #include <stdlib.h>
#
# int main (int argc, char *argv[])
# {
#     printf("Max Available Procs = %d\n", omp_get_num_procs());
#     printf("Max Available Threads = %d\n", omp_get_max_threads());
#     int nthreads, tid;
#
#     #pragma omp parallel private(nthreads, tid)
#     {
#         tid = omp_get_thread_num();
#         nthreads = omp_get_num_threads();
#         printf("Hello World Thread %d / %d\n", tid, nthreads);
#
#
#     }
#
#     return 0;
# }
# Out:
# Overwriting code.c

# %%
#Threads Parallel Region
# %%writefile code.c
#include <stdio.h>
#include <stdlib.h>
#include <omp.h>

int main(int argc, char *argv[]){
  omp_set_num_threads(4);
  printf("Número de Threads fora da região paralela = %d\n", omp_get_num_threads());

  #pragma omp parallel
  {
    int nthreads, id;
    id = omp_get_thread_num();
    printf("Eu sou a thread = %d\n", id);

    if(id == 0){
      nthreads = omp_get_num_threads();
      printf("Número de Threads na região paralela = %d\n", nthreads);
    }

  }
  return 0;

}
# Out:
# Overwriting code.c

# %%
#For directive

# %%writefile code.c
#include <stdio.h>
#include <stdlib.h>
#include <omp.h>
#define N 20
int main(int argc, char *argv[]){

  int i, n;
  float a[N], b[N], c[N];

  for (i=0; i < N; i++){
    a[i] = b[i] = i * 1.0;
  }
  n = N;

  #pragma omp parallel num_threads(4)
  {
    int id = omp_get_thread_num();
    #pragma omp for
    for (i=0; i < n; i++) {
        c[i] = a[i] + b[i];
        printf("thread %d executa a iteração %d do loop\n", id, i);
    }
  }




}
# Out:
# Overwriting code.c

# %%
# Sections
# %%writefile code.c
#include <stdio.h>
#include <stdlib.h>
#include <omp.h>
int main(int argc, char *argv[])
{
    int secao = 0;

    #pragma omp parallel sections
    {
        #pragma omp section
        {
            int id = omp_get_threads_num();
            secao++;
            printf("Ordem de execução da sessão %d, thread %d\n", secao, id);
        }

        #pragma omp section
        {
            int id = omp_get_thread_num();
            secao++;
            printf("Ordem de execução da sessão %d, thread %d\n", secao, id);
        }
    }
}
# Out:
# Overwriting code.c

# %%
# Single
# %%writefile code.c
#include <stdio.h>
#include <stdlib.h>
#include <omp.h>
#define N 20

int main(int argc, char *argv[])
{
    float a[N], b[N], c[N];
    #pragma omp parallel
        #pragma omp single
        printf("Inicio da região paralela número de threads = % d\n", omp_get_thread_num());
        #pragma omp for
        for (int i = 0; i < N; i++)
        {
            c[i] = a[i] + b[i];
            printf("Thread % d executa a iteração % d do loop\n", omp_get_thread_num(), i);
        }

}
# Out:
# Overwriting code.c

# %%
# Sections task
# %%writefile code.c

#include <stdio.h>
#include <omp.h>
#include <stdlib.h>
#include <time.h>
//Aluno: Kalil Saldanha Kaliffe // 202004940030
int main () {

	int arr1[10], arr2[10], arrSum[10], arrSum1[10], arrSub[10];
	int nthreads, tid, tidSec1, tidSec2;
	nthreads = omp_get_num_threads();
	for(int i = 0; i < 10; i++){
		arr1[i] = i + rand() % 24;
		arr2[i] = i + rand() % 24;
	}

	#pragma omp parallel
	{
		tid = omp_get_thread_num();
		#pragma omp for
		for(int i = 0; i < 10; i++){

			arrSum[i] = arr1[i] + arr2[i];
			printf("\nArr soma Id Thread: %d / %d - Iteracao: %d - valor calc: %d \n", tid, nthreads, i, arrSum[i]);

		}
	}
	#pragma omp parallel sections
	{

		#pragma omp section
		{
	    tidSec1 = omp_get_thread_num();
		for(int i = 0; i < 10; i++){

			arrSum1[i] = arr1[i] + arr2[i];
			printf("\nArr soma - Id Thread: %d / %d - Iteracao: %d - valor calc: %d \n", tid, nthreads, i, arrSum1[i]);

		}
		}

		#pragma omp section
		{
	    tidSec2 = omp_get_thread_num();
		for(int i = 0; i < 10; i++){

			arrSub[i] = arr1[i] - arr2[i];
			printf("\nArr Subtracao - Id Thread: %d / %d - Iteracao: %d - valor calc: %d \n", tid, nthreads, i, arrSub[i]);

		}
		}

	}

	printf("\n Fim do programa \n");


	return 0;

}
# Out:
# Overwriting code.c

# %%
# Barrier
# %%writefile code.c

#include <omp.h>
#include <stdio.h>
#include <stdlib.h>

int main(int argc, char* argv[])
{

    #pragma omp parallel num_threads(4)
    {
      int id = omp_get_thread_num();
      int num_threads = omp_get_num_threads();

      if(id == 0){
        printf("Estou atrasada para a barreira ! Tecle enter \\n ");
        getchar();
      }
      #pragma omp barrier
        printf("Cheguei na barreira. Eu sou a %d de %d threads \\n", id, num_threads);
    }
    return 0;
}
# Out:
# Overwriting code.c

# %%
# Master
# %%writefile code.c
#include <omp.h>
#include <stdio.h>
#include <stdlib.h>

int main(int argc, char* argv[])
{
  int a, i, n=5, b[n];
  #pragma omp parallel shared(a,b) private(i)
  {
    #pragma omp master
    {
      a = 10;
      printf("Construtor master é executado pela thread %d\n", omp_get_thread_num());
    }
    #pragma omp barrier

    #pragma omp for
      for(i = 0; i < n; i++)
        b[i] = a;


  }
      printf("Apos a regiao paralela: \n");
      for(i =0; i < n ; i++)
        printf("b[%d] = %d\n", i, b[i]);
}
# Out:
# Overwriting code.c

# %%
# Critical
# %%writefile code.c
#include <stdio.h>
#include <stdlib.h>
#include <omp.h>
#define N 5

int main(int argc, char *argv[])
{
    int i, id, n;
    float a[N];
    float sum = 0.0, sumLocal = 0.0;

    for (i=0; i < N; i++) {
        a[i] = i*1.0;
    }
    n = N;

    #pragma omp parallel shared(n,sum) private(id,sumLocal)
    {
        id = omp_get_thread_num();

        #pragma omp of
        for (i=0; i < n; i++) {
            sumLocal += a[i];
        }

        #pragma omp critical(soma_local)
        {
            sum += sumLocal;
            printf("Id = %d: sumLocal = %f: sum = %f:\n", id, sumLocal, sum);

        }
    }
    printf("Valor da soma após a região paralela: %f\n", sum);
}
# Out:
# Overwriting code.c

# %%
# Atomic
# %%writefile code.c
#include <stdio.h>
#include <stdlib.h>
#include <omp.h>
#define N 5

int main(int argc, char *argv[])
{
    int i, id, n;
    float a[N];
    float sum = 0.0, sumLocal = 0.0;

    for (i=0; i < N; i++) {
        a[i] = i*1.0;
    }
    n = N;

    #pragma omp parallel shared(n,sum) private(id,sumLocal)
    {
        id = omp_get_thread_num();

        #pragma omp of
        for (i=0; i < n; i++) {
            sumLocal += a[i];
        }

        #pragma omp atomic update

            sum += sumLocal;
            printf("Id = %d: sumLocal = %f: sum = %f:\n", id, sumLocal, sum);


    }
    printf("Valor da soma após a região paralela: %f\n", sum);
}
# Out:
# Overwriting code.c

# %%
# 1. #pragma omp parallel shared (a,b,c,n) private (id,i) {
# 2. #pragma omp for
# 3. for (i = 0; i < n; i++) {
# 4. id = omp_get_thread_num();
# 5. c[i] = a[i] + b[i];
# 6. printf(“Thread %d executa a iteração %d do
# 7. loop\n”, id,i);
# 8. }
# 9. }

# %%
# 1. double media = 0.0f, A[N]; int i;
# 2. #pragma omp parallel for reduction (+:media)
# 3. for (i = 0; i < N; i++) {
# 4. media += A[i];
# 5. }
# 6. media = media/N;

# %%
# Reduction
# %%writefile code.c
#include <stdio.h>
#include <stdlib.h>
#include <omp.h>
#define SOMA_INICIAL 1000

int main(int argc, char *argv[])
{
    int i, n = 25;
    int a[n], soma;
    int ref = SOMA_INICIAL + ((n-1)*n)/2;

    omp_set_num_threads (4);

    for (i=0; i < n; i++){
        a[i] = i;
    }
        soma = SOMA_INICIAL;
        printf("Valor da soma antes da região paralela: %d\n", soma);

    #pragma omp parallel default(none) shared(n,a) reduction(+:soma)
    {
        soma = 0;

        #pragma omp for
            for (i=0; i < n; i++) {
                soma += a[i];
            }
            printf("Valor Soma na Threads:%d é igual %d\n", omp_get_thread_num(), soma);

    }
    printf("Valor da Soma Depois da Região Paralela: %d\n", soma);
    printf("Verificação do Resultado: soma %d (deveria ser %d)\n", soma, ref);
}
# Out:
# Overwriting code.c

# %%
# Case Study: Counting Prime Numbers
# %%writefile primos.c
#include <stdio.h>
#include <stdlib.h>
#include <math.h>
#include <omp.h>
#define SOMA_INICIAL 1000

int primo (long int n) {
    long int i;

    for (i = 3; i < (sqrt(n) + 1); i+=2) {
        if (n%i == 0) {
            return 0;
        }
        printf("Primo! -> %ld\n", n);
        return 1;
    }
}

int main(int argc, char *argv[])
{
   double t_inicio, t_fim;
   long int i, n, total;
    if (argc < 2) {
        printf("Valor inválido! Entre com o valor do maior inteiro\n");
        return 0;
    }
    else {
        n = strtol(argv[1], (char **) NULL, 10);
    }
    total = 0;
    t_inicio = omp_get_wtime();

    #pragma omp parallel for reduction(+:total) schedule(static)
        for (i = 3; i <= n; i += 2) {
            if (primo(i) == 1) {
                total++;
            }
        }
        total += 1;
    t_fim = omp_get_wtime();
    printf("Quantidade de Primos entre 1 e %ld: %ld\n", n, total);
    printf("Tempo de execução: %f com %d threads\n", (t_fim - t_inicio), omp_get_max_threads());

    return 0;
}
# Out:
# Overwriting primos.c

# %%
# !gcc -o primos primos.c -fopenmp -O3 -std=c11 -lm
# !./primos 5000
# Out:
# Primo! -> 5
# Primo! -> 7
# Primo! -> 11
# Primo! -> 13
# Primo! -> 17
# Primo! -> 19
# Primo! -> 23
# Primo! -> 25
# Primo! -> 29
# Primo! -> 31
# Primo! -> 35
# Primo! -> 37
# Primo! -> 41
# Primo! -> 43
# Primo! -> 47
# Primo! -> 49
# Primo! -> 53
# Primo! -> 55
# Primo! -> 59
# Primo! -> 61
# Primo! -> 65
# Primo! -> 67
# Primo! -> 71
# Primo! -> 73
# Primo! -> 77
# Primo! -> 79
# Primo! -> 83
# Primo! -> 85
# Primo! -> 89
# Primo! -> 91
# Primo! -> 95
# Primo! -> 97
# Primo! -> 101
# Primo! -> 103
# Primo! -> 107
# Primo! -> 109
# Primo! -> 113
# Primo! -> 115
# Primo! -> 119
# Primo! -> 121
# Primo! -> 125
# Primo! -> 127
# Primo! -> 131
# Primo! -> 133
# Primo! -> 137
# Primo! -> 139
# Primo! -> 143
# Primo! -> 145
# Primo! -> 149
# Primo! -> 151
# Primo! -> 155
# Primo! -> 157
# Primo! -> 161
# Primo! -> 163
# Primo! -> 167
# Primo! -> 169
# Primo! -> 173
# Primo! -> 175
# Primo! -> 179
# Primo! -> 181
# Primo! -> 185
# Primo! -> 187
# Primo! -> 191
# Primo! -> 193
# Primo! -> 197
# Primo! -> 199
# Primo! -> 203
# Primo! -> 205
# Primo! -> 209
# Primo! -> 211
# Primo! -> 215
# Primo! -> 217
# Primo! -> 221
# Primo! -> 223
# Primo! -> 227
# Primo! -> 229
# Primo! -> 233
# Primo! -> 235
# Primo! -> 239
# Primo! -> 241
# Primo! -> 245
# Primo! -> 247
# Primo! -> 251
# Primo! -> 253
# Primo! -> 257
# Primo! -> 259
# Primo! -> 263
# Primo! -> 265
# Primo! -> 269
# Primo! -> 271
# Primo! -> 275
# Primo! -> 277
# Primo! -> 281
# Primo! -> 283
# Primo! -> 287
# Primo! -> 289
# Primo! -> 293
# Primo! -> 295
# Primo! -> 299
# Primo! -> 301
# Primo! -> 305
# Primo! -> 307
# Primo! -> 311
# Primo! -> 313
# Primo! -> 317
# Primo! -> 319
# Primo! -> 323
# Primo! -> 325
# Primo! -> 329
# Primo! -> 331
# Primo! -> 335
# Primo! -> 337
# Primo! -> 341
# Primo! -> 343
# Primo! -> 347
# Primo! -> 349
# Primo! -> 353
# Primo! -> 355
# Primo! -> 359
# Primo! -> 361
# Primo! -> 365
# Primo! -> 367
# Primo! -> 371
# Primo! -> 373
# Primo! -> 377
# Primo! -> 379
# Primo! -> 383
# Primo! -> 385
# Primo! -> 389
# Primo! -> 391
# Primo! -> 395
# Primo! -> 397
# Primo! -> 401
# Primo! -> 403
# Primo! -> 407
# Primo! -> 409
# Primo! -> 413
# Primo! -> 415
# Primo! -> 419
# Primo! -> 421
# Primo! -> 425
# Primo! -> 427
# Primo! -> 431
# Primo! -> 433
# Primo! -> 437
# Primo! -> 439
# Primo! -> 443
# Primo! -> 445
# Primo! -> 449
# Primo! -> 451
# Primo! -> 455
# Primo! -> 457
# Primo! -> 461
# Primo! -> 463
# Primo! -> 467
# Primo! -> 469
# Primo! -> 473
# Primo! -> 475
# Primo! -> 479
# Primo! -> 481
# Primo! -> 485
# Primo! -> 487
# Primo! -> 491
# Primo! -> 493
# Primo! -> 497
# Primo! -> 499
# Primo! -> 503
# Primo! -> 505
# Primo! -> 509
# Primo! -> 511
# Primo! -> 515
# Primo! -> 517
# Primo! -> 521
# Primo! -> 523
# Primo! -> 527
# Primo! -> 529
# Primo! -> 533
# Primo! -> 535
# Primo! -> 539
# Primo! -> 541
# Primo! -> 545
# Primo! -> 547
# Primo! -> 551
# Primo! -> 553
# Primo! -> 557
# Primo! -> 559
# Primo! -> 563
# Primo! -> 565
# Primo! -> 569
# Primo! -> 571
# Primo! -> 575
# Primo! -> 577
# Primo! -> 581
# Primo! -> 583
# Primo! -> 587
# Primo! -> 589
# Primo! -> 593
# Primo! -> 595
# Primo! -> 599
# Primo! -> 601
# Primo! -> 605
# Primo! -> 607
# Primo! -> 611
# Primo! -> 613
# Primo! -> 617
# Primo! -> 619
# Primo! -> 623
# Primo! -> 625
# Primo! -> 629
# Primo! -> 631
# Primo! -> 635
# Primo! -> 637
# Primo! -> 641
# Primo! -> 643
# Primo! -> 647
# Primo! -> 649
# Primo! -> 653
# Primo! -> 655
# Primo! -> 659
# Primo! -> 661
# Primo! -> 665
# Primo! -> 667
# Primo! -> 671
# Primo! -> 673
# Primo! -> 677
# Primo! -> 679
# Primo! -> 683
# Primo! -> 685
# Primo! -> 689
# Primo! -> 691
# Primo! -> 695
# Primo! -> 697
# Primo! -> 701
# Primo! -> 703
# Primo! -> 707
# Primo! -> 709
# Primo! -> 713
# Primo! -> 715
# Primo! -> 719
# Primo! -> 721
# Primo! -> 725
# Primo! -> 727
# Primo! -> 731
# Primo! -> 733
# Primo! -> 737
# Primo! -> 739
# Primo! -> 743
# Primo! -> 745
# Primo! -> 749
# Primo! -> 751
# Primo! -> 755
# Primo! -> 757
# Primo! -> 761
# Primo! -> 763
# Primo! -> 767
# Primo! -> 769
# Primo! -> 773
# Primo! -> 775
# Primo! -> 779
# Primo! -> 781
# Primo! -> 785
# Primo! -> 787
# Primo! -> 791
# Primo! -> 793
# Primo! -> 797
# Primo! -> 799
# Primo! -> 803
# Primo! -> 805
# Primo! -> 809
# Primo! -> 811
# Primo! -> 815
# Primo! -> 817
# Primo! -> 821
# Primo! -> 823
# Primo! -> 827
# Primo! -> 829
# Primo! -> 833
# Primo! -> 835
# Primo! -> 839
# Primo! -> 841
# Primo! -> 845
# Primo! -> 847
# Primo! -> 851
# Primo! -> 853
# Primo! -> 857
# Primo! -> 859
# Primo! -> 863
# Primo! -> 865
# Primo! -> 869
# Primo! -> 871
# Primo! -> 875
# Primo! -> 877
# Primo! -> 881
# Primo! -> 883
# Primo! -> 887
# Primo! -> 889
# Primo! -> 893
# Primo! -> 895
# Primo! -> 899
# Primo! -> 901
# Primo! -> 905
# Primo! -> 907
# Primo! -> 911
# Primo! -> 913
# Primo! -> 917
# Primo! -> 919
# Primo! -> 923
# Primo! -> 925
# Primo! -> 929
# Primo! -> 931
# Primo! -> 935
# Primo! -> 937
# Primo! -> 941
# Primo! -> 943
# Primo! -> 947
# Primo! -> 949
# Primo! -> 953
# Primo! -> 955
# Primo! -> 959
# Primo! -> 961
# Primo! -> 965
# Primo! -> 967
# Primo! -> 971
# Primo! -> 973
# Primo! -> 977
# Primo! -> 979
# Primo! -> 983
# Primo! -> 985
# Primo! -> 989
# Primo! -> 991
# Primo! -> 995
# Primo! -> 997
# Primo! -> 1001
# Primo! -> 1003
# Primo! -> 1007
# Primo! -> 1009
# Primo! -> 1013
# Primo! -> 1015
# Primo! -> 1019
# Primo! -> 1021
# Primo! -> 1025
# Primo! -> 1027
# Primo! -> 1031
# Primo! -> 1033
# Primo! -> 1037
# Primo! -> 1039
# Primo! -> 1043
# Primo! -> 1045
# Primo! -> 1049
# Primo! -> 1051
# Primo! -> 1055
# Primo! -> 1057
# Primo! -> 1061
# Primo! -> 1063
# Primo! -> 1067
# Primo! -> 1069
# Primo! -> 1073
# Primo! -> 1075
# Primo! -> 1079
# Primo! -> 1081
# Primo! -> 1085
# Primo! -> 1087
# Primo! -> 1091
# Primo! -> 1093
# Primo! -> 1097
# Primo! -> 1099
# Primo! -> 1103
# Primo! -> 1105
# Primo! -> 1109
# Primo! -> 1111
# Primo! -> 1115
# Primo! -> 1117
# Primo! -> 1121
# Primo! -> 1123
# Primo! -> 1127
# Primo! -> 1129
# Primo! -> 1133
# Primo! -> 1135
# Primo! -> 1139
# Primo! -> 1141
# Primo! -> 1145
# Primo! -> 1147
# Primo! -> 1151
# Primo! -> 1153
# Primo! -> 1157
# Primo! -> 1159
# Primo! -> 1163
# Primo! -> 1165
# Primo! -> 1169
# Primo! -> 1171
# Primo! -> 1175
# Primo! -> 1177
# Primo! -> 1181
# Primo! -> 1183
# Primo! -> 1187
# Primo! -> 1189
# Primo! -> 1193
# Primo! -> 1195
# Primo! -> 1199
# Primo! -> 1201
# Primo! -> 1205
# Primo! -> 1207
# Primo! -> 1211
# Primo! -> 1213
# Primo! -> 1217
# Primo! -> 1219
# Primo! -> 1223
# Primo! -> 1225
# Primo! -> 1229
# Primo! -> 1231
# Primo! -> 1235
# Primo! -> 1237
# Primo! -> 1241
# Primo! -> 1243
# Primo! -> 1247
# Primo! -> 1249
# Primo! -> 2503
# Primo! -> 2507
# Primo! -> 2509
# Primo! -> 2513
# Primo! -> 2515
# Primo! -> 2519
# Primo! -> 2521
# Primo! -> 2525
# Primo! -> 2527
# Primo! -> 2531
# Primo! -> 2533
# Primo! -> 2537
# Primo! -> 2539
# Primo! -> 2543
# Primo! -> 2545
# Primo! -> 2549
# Primo! -> 2551
# Primo! -> 2555
# Primo! -> 2557
# Primo! -> 2561
# Primo! -> 2563
# Primo! -> 2567
# Primo! -> 2569
# Primo! -> 2573
# Primo! -> 2575
# Primo! -> 2579
# Primo! -> 2581
# Primo! -> 2585
# Primo! -> 2587
# Primo! -> 2591
# Primo! -> 2593
# Primo! -> 2597
# Primo! -> 2599
# Primo! -> 2603
# Primo! -> 2605
# Primo! -> 2609
# Primo! -> 2611
# Primo! -> 2615
# Primo! -> 2617
# Primo! -> 2621
# Primo! -> 2623
# Primo! -> 2627
# Primo! -> 2629
# Primo! -> 2633
# Primo! -> 2635
# Primo! -> 2639
# Primo! -> 2641
# Primo! -> 2645
# Primo! -> 2647
# Primo! -> 2651
# Primo! -> 2653
# Primo! -> 2657
# Primo! -> 2659
# Primo! -> 2663
# Primo! -> 2665
# Primo! -> 2669
# Primo! -> 2671
# Primo! -> 2675
# Primo! -> 2677
# Primo! -> 2681
# Primo! -> 2683
# Primo! -> 2687
# Primo! -> 2689
# Primo! -> 2693
# Primo! -> 2695
# Primo! -> 2699
# Primo! -> 2701
# Primo! -> 2705
# Primo! -> 2707
# Primo! -> 2711
# Primo! -> 2713
# Primo! -> 2717
# Primo! -> 2719
# Primo! -> 2723
# Primo! -> 2725
# Primo! -> 2729
# Primo! -> 2731
# Primo! -> 2735
# Primo! -> 2737
# Primo! -> 2741
# Primo! -> 2743
# Primo! -> 2747
# Primo! -> 2749
# Primo! -> 2753
# Primo! -> 2755
# Primo! -> 2759
# Primo! -> 2761
# Primo! -> 2765
# Primo! -> 2767
# Primo! -> 2771
# Primo! -> 2773
# Primo! -> 2777
# Primo! -> 2779
# Primo! -> 2783
# Primo! -> 2785
# Primo! -> 2789
# Primo! -> 2791
# Primo! -> 2795
# Primo! -> 2797
# Primo! -> 2801
# Primo! -> 2803
# Primo! -> 2807
# Primo! -> 2809
# Primo! -> 2813
# Primo! -> 2815
# Primo! -> 2819
# Primo! -> 2821
# Primo! -> 2825
# Primo! -> 2827
# Primo! -> 2831
# Primo! -> 2833
# Primo! -> 2837
# Primo! -> 2839
# Primo! -> 2843
# Primo! -> 2845
# Primo! -> 2849
# Primo! -> 2851
# Primo! -> 2855
# Primo! -> 2857
# Primo! -> 2861
# Primo! -> 2863
# Primo! -> 2867
# Primo! -> 2869
# Primo! -> 2873
# Primo! -> 2875
# Primo! -> 2879
# Primo! -> 2881
# Primo! -> 2885
# Primo! -> 2887
# Primo! -> 2891
# Primo! -> 2893
# Primo! -> 2897
# Primo! -> 2899
# Primo! -> 2903
# Primo! -> 2905
# Primo! -> 2909
# Primo! -> 2911
# Primo! -> 2915
# Primo! -> 2917
# Primo! -> 2921
# Primo! -> 2923
# Primo! -> 2927
# Primo! -> 2929
# Primo! -> 2933
# Primo! -> 2935
# Primo! -> 2939
# Primo! -> 2941
# Primo! -> 2945
# Primo! -> 2947
# Primo! -> 2951
# Primo! -> 2953
# Primo! -> 2957
# Primo! -> 2959
# Primo! -> 2963
# Primo! -> 2965
# Primo! -> 2969
# Primo! -> 2971
# Primo! -> 2975
# Primo! -> 2977
# Primo! -> 2981
# Primo! -> 2983
# Primo! -> 2987
# Primo! -> 2989
# Primo! -> 2993
# Primo! -> 2995
# Primo! -> 2999
# Primo! -> 3001
# Primo! -> 3005
# Primo! -> 3007
# Primo! -> 3011
# Primo! -> 3013
# Primo! -> 3017
# Primo! -> 3019
# Primo! -> 3023
# Primo! -> 3025
# Primo! -> 3029
# Primo! -> 3031
# Primo! -> 3035
# Primo! -> 3037
# Primo! -> 3041
# Primo! -> 3043
# Primo! -> 3047
# Primo! -> 3049
# Primo! -> 3053
# Primo! -> 3055
# Primo! -> 3059
# Primo! -> 3061
# Primo! -> 3065
# Primo! -> 3067
# Primo! -> 3071
# Primo! -> 3073
# Primo! -> 3077
# Primo! -> 3079
# Primo! -> 3083
# Primo! -> 3085
# Primo! -> 3089
# Primo! -> 3091
# Primo! -> 3095
# Primo! -> 3097
# Primo! -> 3101
# Primo! -> 3103
# Primo! -> 3107
# Primo! -> 3109
# Primo! -> 3113
# Primo! -> 3115
# Primo! -> 3119
# Primo! -> 3121
# Primo! -> 3125
# Primo! -> 3127
# Primo! -> 3131
# Primo! -> 3133
# Primo! -> 3137
# Primo! -> 3139
# Primo! -> 3143
# Primo! -> 3145
# Primo! -> 3149
# Primo! -> 3151
# Primo! -> 3155
# Primo! -> 3157
# Primo! -> 3161
# Primo! -> 3163
# Primo! -> 3167
# Primo! -> 3169
# Primo! -> 3173
# Primo! -> 3175
# Primo! -> 3179
# Primo! -> 3181
# Primo! -> 3185
# Primo! -> 3187
# Primo! -> 3191
# Primo! -> 3193
# Primo! -> 3197
# Primo! -> 3199
# Primo! -> 3203
# Primo! -> 3205
# Primo! -> 3209
# Primo! -> 3211
# Primo! -> 3215
# Primo! -> 3217
# Primo! -> 3221
# Primo! -> 3223
# Primo! -> 3227
# Primo! -> 3229
# Primo! -> 3233
# Primo! -> 3235
# Primo! -> 3239
# Primo! -> 3241
# Primo! -> 3245
# Primo! -> 3247
# Primo! -> 3251
# Primo! -> 3253
# Primo! -> 3257
# Primo! -> 3259
# Primo! -> 3263
# Primo! -> 3265
# Primo! -> 3269
# Primo! -> 3271
# Primo! -> 3275
# Primo! -> 3277
# Primo! -> 3281
# Primo! -> 3283
# Primo! -> 3287
# Primo! -> 3289
# Primo! -> 3293
# Primo! -> 3295
# Primo! -> 3299
# Primo! -> 3301
# Primo! -> 3305
# Primo! -> 3307
# Primo! -> 3311
# Primo! -> 3313
# Primo! -> 3317
# Primo! -> 3319
# Primo! -> 3323
# Primo! -> 3325
# Primo! -> 3329
# Primo! -> 3331
# Primo! -> 3335
# Primo! -> 3337
# Primo! -> 3341
# Primo! -> 3343
# Primo! -> 3347
# Primo! -> 3349
# Primo! -> 3353
# Primo! -> 3355
# Primo! -> 3359
# Primo! -> 3361
# Primo! -> 3365
# Primo! -> 3367
# Primo! -> 3371
# Primo! -> 3373
# Primo! -> 3377
# Primo! -> 3379
# Primo! -> 3383
# Primo! -> 3385
# Primo! -> 3389
# Primo! -> 3391
# Primo! -> 3395
# Primo! -> 3397
# Primo! -> 3401
# Primo! -> 3403
# Primo! -> 3407
# Primo! -> 3409
# Primo! -> 3413
# Primo! -> 3415
# Primo! -> 3419
# Primo! -> 3421
# Primo! -> 3425
# Primo! -> 3427
# Primo! -> 3431
# Primo! -> 3433
# Primo! -> 3437
# Primo! -> 3439
# Primo! -> 3443
# Primo! -> 3445
# Primo! -> 3449
# Primo! -> 3451
# Primo! -> 3455
# Primo! -> 3457
# Primo! -> 3461
# Primo! -> 3463
# Primo! -> 3467
# Primo! -> 3469
# Primo! -> 3473
# Primo! -> 3475
# Primo! -> 3479
# Primo! -> 3481
# Primo! -> 3485
# Primo! -> 3487
# Primo! -> 3491
# Primo! -> 3493
# Primo! -> 3497
# Primo! -> 3499
# Primo! -> 3503
# Primo! -> 3505
# Primo! -> 3509
# Primo! -> 3511
# Primo! -> 3515
# Primo! -> 3517
# Primo! -> 3521
# Primo! -> 3523
# Primo! -> 3527
# Primo! -> 3529
# Primo! -> 3533
# Primo! -> 3535
# Primo! -> 3539
# Primo! -> 3541
# Primo! -> 3545
# Primo! -> 3547
# Primo! -> 3551
# Primo! -> 3553
# Primo! -> 3557
# Primo! -> 3559
# Primo! -> 3563
# Primo! -> 3565
# Primo! -> 3569
# Primo! -> 3571
# Primo! -> 3575
# Primo! -> 3577
# Primo! -> 3581
# Primo! -> 3583
# Primo! -> 3587
# Primo! -> 3589
# Primo! -> 3593
# Primo! -> 3595
# Primo! -> 3599
# Primo! -> 3601
# Primo! -> 3605
# Primo! -> 3607
# Primo! -> 3611
# Primo! -> 3613
# Primo! -> 3617
# Primo! -> 3619
# Primo! -> 3623
# Primo! -> 3625
# Primo! -> 3629
# Primo! -> 3631
# Primo! -> 3635
# Primo! -> 3637
# Primo! -> 3641
# Primo! -> 3643
# Primo! -> 3647
# Primo! -> 3649
# Primo! -> 3653
# Primo! -> 3655
# Primo! -> 3659
# Primo! -> 3661
# Primo! -> 3665
# Primo! -> 3667
# Primo! -> 3671
# Primo! -> 3673
# Primo! -> 3677
# Primo! -> 3679
# Primo! -> 3683
# Primo! -> 3685
# Primo! -> 3689
# Primo! -> 3691
# Primo! -> 3695
# Primo! -> 3697
# Primo! -> 3701
# Primo! -> 3703
# Primo! -> 3707
# Primo! -> 3709
# Primo! -> 3713
# Primo! -> 3715
# Primo! -> 3719
# Primo! -> 3721
# Primo! -> 3725
# Primo! -> 3727
# Primo! -> 3731
# Primo! -> 3733
# Primo! -> 3737
# Primo! -> 3739
# Primo! -> 3743
# Primo! -> 3745
# Primo! -> 3749
# Primo! -> 3751
# Primo! -> 1253
# Primo! -> 1255
# Primo! -> 1259
# Primo! -> 1261
# Primo! -> 1265
# Primo! -> 1267
# Primo! -> 1271
# Primo! -> 1273
# Primo! -> 1277
# Primo! -> 1279
# Primo! -> 1283
# Primo! -> 1285
# Primo! -> 1289
# Primo! -> 1291
# Primo! -> 1295
# Primo! -> 1297
# Primo! -> 1301
# Primo! -> 1303
# Primo! -> 1307
# Primo! -> 1309
# Primo! -> 1313
# Primo! -> 1315
# Primo! -> 1319
# Primo! -> 1321
# Primo! -> 1325
# Primo! -> 1327
# Primo! -> 1331
# Primo! -> 1333
# Primo! -> 1337
# Primo! -> 1339
# Primo! -> 1343
# Primo! -> 1345
# Primo! -> 1349
# Primo! -> 1351
# Primo! -> 1355
# Primo! -> 1357
# Primo! -> 1361
# Primo! -> 1363
# Primo! -> 1367
# Primo! -> 1369
# Primo! -> 1373
# Primo! -> 1375
# Primo! -> 1379
# Primo! -> 1381
# Primo! -> 1385
# Primo! -> 1387
# Primo! -> 1391
# Primo! -> 1393
# Primo! -> 1397
# Primo! -> 1399
# Primo! -> 1403
# Primo! -> 1405
# Primo! -> 1409
# Primo! -> 1411
# Primo! -> 1415
# Primo! -> 1417
# Primo! -> 1421
# Primo! -> 1423
# Primo! -> 1427
# Primo! -> 1429
# Primo! -> 1433
# Primo! -> 1435
# Primo! -> 1439
# Primo! -> 1441
# Primo! -> 1445
# Primo! -> 1447
# Primo! -> 1451
# Primo! -> 1453
# Primo! -> 1457
# Primo! -> 1459
# Primo! -> 1463
# Primo! -> 1465
# Primo! -> 1469
# Primo! -> 1471
# Primo! -> 1475
# Primo! -> 1477
# Primo! -> 1481
# Primo! -> 1483
# Primo! -> 1487
# Primo! -> 1489
# Primo! -> 1493
# Primo! -> 1495
# Primo! -> 1499
# Primo! -> 1501
# Primo! -> 1505
# Primo! -> 1507
# Primo! -> 1511
# Primo! -> 1513
# Primo! -> 1517
# Primo! -> 1519
# Primo! -> 1523
# Primo! -> 1525
# Primo! -> 1529
# Primo! -> 1531
# Primo! -> 1535
# Primo! -> 1537
# Primo! -> 1541
# Primo! -> 1543
# Primo! -> 1547
# Primo! -> 1549
# Primo! -> 1553
# Primo! -> 1555
# Primo! -> 1559
# Primo! -> 1561
# Primo! -> 1565
# Primo! -> 1567
# Primo! -> 1571
# Primo! -> 1573
# Primo! -> 1577
# Primo! -> 1579
# Primo! -> 1583
# Primo! -> 1585
# Primo! -> 1589
# Primo! -> 1591
# Primo! -> 1595
# Primo! -> 1597
# Primo! -> 1601
# Primo! -> 1603
# Primo! -> 1607
# Primo! -> 1609
# Primo! -> 1613
# Primo! -> 1615
# Primo! -> 1619
# Primo! -> 1621
# Primo! -> 1625
# Primo! -> 1627
# Primo! -> 1631
# Primo! -> 1633
# Primo! -> 1637
# Primo! -> 1639
# Primo! -> 1643
# Primo! -> 1645
# Primo! -> 1649
# Primo! -> 1651
# Primo! -> 1655
# Primo! -> 1657
# Primo! -> 1661
# Primo! -> 1663
# Primo! -> 1667
# Primo! -> 1669
# Primo! -> 1673
# Primo! -> 1675
# Primo! -> 1679
# Primo! -> 1681
# Primo! -> 1685
# Primo! -> 1687
# Primo! -> 1691
# Primo! -> 1693
# Primo! -> 1697
# Primo! -> 1699
# Primo! -> 1703
# Primo! -> 1705
# Primo! -> 1709
# Primo! -> 1711
# Primo! -> 1715
# Primo! -> 1717
# Primo! -> 1721
# Primo! -> 1723
# Primo! -> 1727
# Primo! -> 1729
# Primo! -> 1733
# Primo! -> 1735
# Primo! -> 1739
# Primo! -> 1741
# Primo! -> 1745
# Primo! -> 1747
# Primo! -> 1751
# Primo! -> 1753
# Primo! -> 1757
# Primo! -> 1759
# Primo! -> 1763
# Primo! -> 1765
# Primo! -> 1769
# Primo! -> 1771
# Primo! -> 1775
# Primo! -> 1777
# Primo! -> 1781
# Primo! -> 1783
# Primo! -> 1787
# Primo! -> 1789
# Primo! -> 1793
# Primo! -> 1795
# Primo! -> 1799
# Primo! -> 1801
# Primo! -> 1805
# Primo! -> 1807
# Primo! -> 1811
# Primo! -> 1813
# Primo! -> 1817
# Primo! -> 1819
# Primo! -> 1823
# Primo! -> 1825
# Primo! -> 1829
# Primo! -> 1831
# Primo! -> 1835
# Primo! -> 1837
# Primo! -> 1841
# Primo! -> 1843
# Primo! -> 1847
# Primo! -> 1849
# Primo! -> 1853
# Primo! -> 1855
# Primo! -> 1859
# Primo! -> 1861
# Primo! -> 1865
# Primo! -> 1867
# Primo! -> 1871
# Primo! -> 1873
# Primo! -> 1877
# Primo! -> 1879
# Primo! -> 1883
# Primo! -> 1885
# Primo! -> 1889
# Primo! -> 1891
# Primo! -> 1895
# Primo! -> 1897
# Primo! -> 1901
# Primo! -> 1903
# Primo! -> 1907
# Primo! -> 1909
# Primo! -> 1913
# Primo! -> 1915
# Primo! -> 1919
# Primo! -> 1921
# Primo! -> 1925
# Primo! -> 1927
# Primo! -> 1931
# Primo! -> 1933
# Primo! -> 1937
# Primo! -> 1939
# Primo! -> 1943
# Primo! -> 1945
# Primo! -> 1949
# Primo! -> 1951
# Primo! -> 1955
# Primo! -> 1957
# Primo! -> 1961
# Primo! -> 1963
# Primo! -> 1967
# Primo! -> 1969
# Primo! -> 1973
# Primo! -> 1975
# Primo! -> 1979
# Primo! -> 1981
# Primo! -> 1985
# Primo! -> 1987
# Primo! -> 1991
# Primo! -> 1993
# Primo! -> 1997
# Primo! -> 1999
# Primo! -> 2003
# Primo! -> 2005
# Primo! -> 2009
# Primo! -> 2011
# Primo! -> 2015
# Primo! -> 2017
# Primo! -> 2021
# Primo! -> 2023
# Primo! -> 2027
# Primo! -> 2029
# Primo! -> 2033
# Primo! -> 2035
# Primo! -> 2039
# Primo! -> 2041
# Primo! -> 2045
# Primo! -> 2047
# Primo! -> 2051
# Primo! -> 2053
# Primo! -> 2057
# Primo! -> 2059
# Primo! -> 2063
# Primo! -> 2065
# Primo! -> 2069
# Primo! -> 2071
# Primo! -> 2075
# Primo! -> 2077
# Primo! -> 2081
# Primo! -> 2083
# Primo! -> 2087
# Primo! -> 2089
# Primo! -> 2093
# Primo! -> 2095
# Primo! -> 2099
# Primo! -> 2101
# Primo! -> 2105
# Primo! -> 2107
# Primo! -> 2111
# Primo! -> 2113
# Primo! -> 2117
# Primo! -> 2119
# Primo! -> 2123
# Primo! -> 2125
# Primo! -> 2129
# Primo! -> 2131
# Primo! -> 2135
# Primo! -> 2137
# Primo! -> 2141
# Primo! -> 2143
# Primo! -> 2147
# Primo! -> 2149
# Primo! -> 2153
# Primo! -> 2155
# Primo! -> 2159
# Primo! -> 2161
# Primo! -> 2165
# Primo! -> 2167
# Primo! -> 2171
# Primo! -> 2173
# Primo! -> 2177
# Primo! -> 2179
# Primo! -> 2183
# Primo! -> 2185
# Primo! -> 2189
# Primo! -> 2191
# Primo! -> 2195
# Primo! -> 2197
# Primo! -> 2201
# Primo! -> 2203
# Primo! -> 2207
# Primo! -> 2209
# Primo! -> 2213
# Primo! -> 2215
# Primo! -> 2219
# Primo! -> 2221
# Primo! -> 2225
# Primo! -> 2227
# Primo! -> 2231
# Primo! -> 2233
# Primo! -> 2237
# Primo! -> 2239
# Primo! -> 2243
# Primo! -> 2245
# Primo! -> 2249
# Primo! -> 2251
# Primo! -> 2255
# Primo! -> 2257
# Primo! -> 2261
# Primo! -> 2263
# Primo! -> 2267
# Primo! -> 2269
# Primo! -> 2273
# Primo! -> 2275
# Primo! -> 2279
# Primo! -> 2281
# Primo! -> 2285
# Primo! -> 2287
# Primo! -> 2291
# Primo! -> 2293
# Primo! -> 2297
# Primo! -> 2299
# Primo! -> 2303
# Primo! -> 2305
# Primo! -> 2309
# Primo! -> 2311
# Primo! -> 2315
# Primo! -> 2317
# Primo! -> 2321
# Primo! -> 2323
# Primo! -> 2327
# Primo! -> 2329
# Primo! -> 2333
# Primo! -> 2335
# Primo! -> 2339
# Primo! -> 2341
# Primo! -> 2345
# Primo! -> 2347
# Primo! -> 2351
# Primo! -> 2353
# Primo! -> 2357
# Primo! -> 2359
# Primo! -> 2363
# Primo! -> 2365
# Primo! -> 2369
# Primo! -> 2371
# Primo! -> 2375
# Primo! -> 2377
# Primo! -> 2381
# Primo! -> 2383
# Primo! -> 2387
# Primo! -> 2389
# Primo! -> 2393
# Primo! -> 2395
# Primo! -> 2399
# Primo! -> 2401
# Primo! -> 2405
# Primo! -> 2407
# Primo! -> 2411
# Primo! -> 2413
# Primo! -> 2417
# Primo! -> 2419
# Primo! -> 2423
# Primo! -> 2425
# Primo! -> 2429
# Primo! -> 2431
# Primo! -> 2435
# Primo! -> 2437
# Primo! -> 2441
# Primo! -> 2443
# Primo! -> 2447
# Primo! -> 2449
# Primo! -> 2453
# Primo! -> 2455
# Primo! -> 2459
# Primo! -> 2461
# Primo! -> 2465
# Primo! -> 2467
# Primo! -> 2471
# Primo! -> 2473
# Primo! -> 2477
# Primo! -> 2479
# Primo! -> 2483
# Primo! -> 2485
# Primo! -> 2489
# Primo! -> 2491
# Primo! -> 2495
# Primo! -> 2497
# Primo! -> 2501
# Primo! -> 3755
# Primo! -> 3757
# Primo! -> 3761
# Primo! -> 3763
# Primo! -> 3767
# Primo! -> 3769
# Primo! -> 3773
# Primo! -> 3775
# Primo! -> 3779
# Primo! -> 3781
# Primo! -> 3785
# Primo! -> 3787
# Primo! -> 3791
# Primo! -> 3793
# Primo! -> 3797
# Primo! -> 3799
# Primo! -> 3803
# Primo! -> 3805
# Primo! -> 3809
# Primo! -> 3811
# Primo! -> 3815
# Primo! -> 3817
# Primo! -> 3821
# Primo! -> 3823
# Primo! -> 3827
# Primo! -> 3829
# Primo! -> 3833
# Primo! -> 3835
# Primo! -> 3839
# Primo! -> 3841
# Primo! -> 3845
# Primo! -> 3847
# Primo! -> 3851
# Primo! -> 3853
# Primo! -> 3857
# Primo! -> 3859
# Primo! -> 3863
# Primo! -> 3865
# Primo! -> 3869
# Primo! -> 3871
# Primo! -> 3875
# Primo! -> 3877
# Primo! -> 3881
# Primo! -> 3883
# Primo! -> 3887
# Primo! -> 3889
# Primo! -> 3893
# Primo! -> 3895
# Primo! -> 3899
# Primo! -> 3901
# Primo! -> 3905
# Primo! -> 3907
# Primo! -> 3911
# Primo! -> 3913
# Primo! -> 3917
# Primo! -> 3919
# Primo! -> 3923
# Primo! -> 3925
# Primo! -> 3929
# Primo! -> 3931
# Primo! -> 3935
# Primo! -> 3937
# Primo! -> 3941
# Primo! -> 3943
# Primo! -> 3947
# Primo! -> 3949
# Primo! -> 3953
# Primo! -> 3955
# Primo! -> 3959
# Primo! -> 3961
# Primo! -> 3965
# Primo! -> 3967
# Primo! -> 3971
# Primo! -> 3973
# Primo! -> 3977
# Primo! -> 3979
# Primo! -> 3983
# Primo! -> 3985
# Primo! -> 3989
# Primo! -> 3991
# Primo! -> 3995
# Primo! -> 3997
# Primo! -> 4001
# Primo! -> 4003
# Primo! -> 4007
# Primo! -> 4009
# Primo! -> 4013
# Primo! -> 4015
# Primo! -> 4019
# Primo! -> 4021
# Primo! -> 4025
# Primo! -> 4027
# Primo! -> 4031
# Primo! -> 4033
# Primo! -> 4037
# Primo! -> 4039
# Primo! -> 4043
# Primo! -> 4045
# Primo! -> 4049
# Primo! -> 4051
# Primo! -> 4055
# Primo! -> 4057
# Primo! -> 4061
# Primo! -> 4063
# Primo! -> 4067
# Primo! -> 4069
# Primo! -> 4073
# Primo! -> 4075
# Primo! -> 4079
# Primo! -> 4081
# Primo! -> 4085
# Primo! -> 4087
# Primo! -> 4091
# Primo! -> 4093
# Primo! -> 4097
# Primo! -> 4099
# Primo! -> 4103
# Primo! -> 4105
# Primo! -> 4109
# Primo! -> 4111
# Primo! -> 4115
# Primo! -> 4117
# Primo! -> 4121
# Primo! -> 4123
# Primo! -> 4127
# Primo! -> 4129
# Primo! -> 4133
# Primo! -> 4135
# Primo! -> 4139
# Primo! -> 4141
# Primo! -> 4145
# Primo! -> 4147
# Primo! -> 4151
# Primo! -> 4153
# Primo! -> 4157
# Primo! -> 4159
# Primo! -> 4163
# Primo! -> 4165
# Primo! -> 4169
# Primo! -> 4171
# Primo! -> 4175
# Primo! -> 4177
# Primo! -> 4181
# Primo! -> 4183
# Primo! -> 4187
# Primo! -> 4189
# Primo! -> 4193
# Primo! -> 4195
# Primo! -> 4199
# Primo! -> 4201
# Primo! -> 4205
# Primo! -> 4207
# Primo! -> 4211
# Primo! -> 4213
# Primo! -> 4217
# Primo! -> 4219
# Primo! -> 4223
# Primo! -> 4225
# Primo! -> 4229
# Primo! -> 4231
# Primo! -> 4235
# Primo! -> 4237
# Primo! -> 4241
# Primo! -> 4243
# Primo! -> 4247
# Primo! -> 4249
# Primo! -> 4253
# Primo! -> 4255
# Primo! -> 4259
# Primo! -> 4261
# Primo! -> 4265
# Primo! -> 4267
# Primo! -> 4271
# Primo! -> 4273
# Primo! -> 4277
# Primo! -> 4279
# Primo! -> 4283
# Primo! -> 4285
# Primo! -> 4289
# Primo! -> 4291
# Primo! -> 4295
# Primo! -> 4297
# Primo! -> 4301
# Primo! -> 4303
# Primo! -> 4307
# Primo! -> 4309
# Primo! -> 4313
# Primo! -> 4315
# Primo! -> 4319
# Primo! -> 4321
# Primo! -> 4325
# Primo! -> 4327
# Primo! -> 4331
# Primo! -> 4333
# Primo! -> 4337
# Primo! -> 4339
# Primo! -> 4343
# Primo! -> 4345
# Primo! -> 4349
# Primo! -> 4351
# Primo! -> 4355
# Primo! -> 4357
# Primo! -> 4361
# Primo! -> 4363
# Primo! -> 4367
# Primo! -> 4369
# Primo! -> 4373
# Primo! -> 4375
# Primo! -> 4379
# Primo! -> 4381
# Primo! -> 4385
# Primo! -> 4387
# Primo! -> 4391
# Primo! -> 4393
# Primo! -> 4397
# Primo! -> 4399
# Primo! -> 4403
# Primo! -> 4405
# Primo! -> 4409
# Primo! -> 4411
# Primo! -> 4415
# Primo! -> 4417
# Primo! -> 4421
# Primo! -> 4423
# Primo! -> 4427
# Primo! -> 4429
# Primo! -> 4433
# Primo! -> 4435
# Primo! -> 4439
# Primo! -> 4441
# Primo! -> 4445
# Primo! -> 4447
# Primo! -> 4451
# Primo! -> 4453
# Primo! -> 4457
# Primo! -> 4459
# Primo! -> 4463
# Primo! -> 4465
# Primo! -> 4469
# Primo! -> 4471
# Primo! -> 4475
# Primo! -> 4477
# Primo! -> 4481
# Primo! -> 4483
# Primo! -> 4487
# Primo! -> 4489
# Primo! -> 4493
# Primo! -> 4495
# Primo! -> 4499
# Primo! -> 4501
# Primo! -> 4505
# Primo! -> 4507
# Primo! -> 4511
# Primo! -> 4513
# Primo! -> 4517
# Primo! -> 4519
# Primo! -> 4523
# Primo! -> 4525
# Primo! -> 4529
# Primo! -> 4531
# Primo! -> 4535
# Primo! -> 4537
# Primo! -> 4541
# Primo! -> 4543
# Primo! -> 4547
# Primo! -> 4549
# Primo! -> 4553
# Primo! -> 4555
# Primo! -> 4559
# Primo! -> 4561
# Primo! -> 4565
# Primo! -> 4567
# Primo! -> 4571
# Primo! -> 4573
# Primo! -> 4577
# Primo! -> 4579
# Primo! -> 4583
# Primo! -> 4585
# Primo! -> 4589
# Primo! -> 4591
# Primo! -> 4595
# Primo! -> 4597
# Primo! -> 4601
# Primo! -> 4603
# Primo! -> 4607
# Primo! -> 4609
# Primo! -> 4613
# Primo! -> 4615
# Primo! -> 4619
# Primo! -> 4621
# Primo! -> 4625
# Primo! -> 4627
# Primo! -> 4631
# Primo! -> 4633
# Primo! -> 4637
# Primo! -> 4639
# Primo! -> 4643
# Primo! -> 4645
# Primo! -> 4649
# Primo! -> 4651
# Primo! -> 4655
# Primo! -> 4657
# Primo! -> 4661
# Primo! -> 4663
# Primo! -> 4667
# Primo! -> 4669
# Primo! -> 4673
# Primo! -> 4675
# Primo! -> 4679
# Primo! -> 4681
# Primo! -> 4685
# Primo! -> 4687
# Primo! -> 4691
# Primo! -> 4693
# Primo! -> 4697
# Primo! -> 4699
# Primo! -> 4703
# Primo! -> 4705
# Primo! -> 4709
# Primo! -> 4711
# Primo! -> 4715
# Primo! -> 4717
# Primo! -> 4721
# Primo! -> 4723
# Primo! -> 4727
# Primo! -> 4729
# Primo! -> 4733
# Primo! -> 4735
# Primo! -> 4739
# Primo! -> 4741
# Primo! -> 4745
# Primo! -> 4747
# Primo! -> 4751
# Primo! -> 4753
# Primo! -> 4757
# Primo! -> 4759
# Primo! -> 4763
# Primo! -> 4765
# Primo! -> 4769
# Primo! -> 4771
# Primo! -> 4775
# Primo! -> 4777
# Primo! -> 4781
# Primo! -> 4783
# Primo! -> 4787
# Primo! -> 4789
# Primo! -> 4793
# Primo! -> 4795
# Primo! -> 4799
# Primo! -> 4801
# Primo! -> 4805
# Primo! -> 4807
# Primo! -> 4811
# Primo! -> 4813
# Primo! -> 4817
# Primo! -> 4819
# Primo! -> 4823
# Primo! -> 4825
# Primo! -> 4829
# Primo! -> 4831
# Primo! -> 4835
# Primo! -> 4837
# Primo! -> 4841
# Primo! -> 4843
# Primo! -> 4847
# Primo! -> 4849
# Primo! -> 4853
# Primo! -> 4855
# Primo! -> 4859
# Primo! -> 4861
# Primo! -> 4865
# Primo! -> 4867
# Primo! -> 4871
# Primo! -> 4873
# Primo! -> 4877
# Primo! -> 4879
# Primo! -> 4883
# Primo! -> 4885
# Primo! -> 4889
# Primo! -> 4891
# Primo! -> 4895
# Primo! -> 4897
# Primo! -> 4901
# Primo! -> 4903
# Primo! -> 4907
# Primo! -> 4909
# Primo! -> 4913
# Primo! -> 4915
# Primo! -> 4919
# Primo! -> 4921
# Primo! -> 4925
# Primo! -> 4927
# Primo! -> 4931
# Primo! -> 4933
# Primo! -> 4937
# Primo! -> 4939
# Primo! -> 4943
# Primo! -> 4945
# Primo! -> 4949
# Primo! -> 4951
# Primo! -> 4955
# Primo! -> 4957
# Primo! -> 4961
# Primo! -> 4963
# Primo! -> 4967
# Primo! -> 4969
# Primo! -> 4973
# Primo! -> 4975
# Primo! -> 4979
# Primo! -> 4981
# Primo! -> 4985
# Primo! -> 4987
# Primo! -> 4991
# Primo! -> 4993
# Primo! -> 4997
# Primo! -> 4999
# Quantidade de Primos entre 1 e 5000: 1667
# Tempo de execução: 0.102965 com 4 threads

# %%
#Time Routine Test
# %%writefile code.c
#include <stdio.h>
#include <stdlib.h>
#include <math.h>
#include <omp.h>
#define N 10000

int main(int argc, char *argv[])
{
    int i, n;
    float a[N], b[N], c[N];
    double inicio, fim;

    inicio = omp_get_wtime();

    for (i=0; i < N; i++) {
        a[i] = b[i] = i * 1.0;
    }
    n = N;

    #pragma omp parallel num_threads(4)
    {
        int id = omp_get_thread_num();

        if (id == 0) {
            int num_procs = omp_get_num_procs();
            int max_threads = omp_get_max_threads();
            printf("Número de processadores disponíveis = %d\n", num_procs);
            printf("Número Máximo de Threads = %d\n", max_threads);
        }
        #pragma omp for
        for (i=0; i < n; i++) {
            c[i] = a[i] + b[i];
            printf("Thread %d executa a iteração %d do loop com valor %f\n", id, i, c[i]);
        }
    }
    fim = omp_get_wtime();
    printf("Tempo de Execução = %3.4f segundos\n", fim - inicio);
    printf("Precisão do Relógio = %3.9f segundos\n", omp_get_wtick());

}
# Out:
# Overwriting code.c

# %%
# Schedule
# %%writefile code.c
#include <stdio.h>
#include <stdlib.h>
#include <omp.h>
#define N 10000

int main(int argc, char *argv[])
{
    printf("Max Available Procs = %d\n", omp_get_num_procs());
    printf("Max Available Threads = %d\n", omp_get_max_threads());
    int i, n = 20;
    printf("Cláusula static SEM o parâmetro tam\n");

    #pragma omp parallel for schedule (static) num_threads (4)
    for (i = 0; i < n; ++i) {
        printf("ID = %d iteração = %d\n", omp_get_thread_num(), i);
    }
    printf("Cláusula static COM o parâmetro tam\n");

    #pragma omp parallel for schedule (static,3) num_threads (4)
        for (i = 0; i < n; i++) {
            printf("ID = %d iteração = %d\n", omp_get_thread_num(),i);
        }
    return 0;
}
# Out:
# Overwriting code.c

# %%
# %env OMP_NUM_THREADS=

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2022 NVIDIA Corporation
# Built on Wed_Sep_21_10:33:58_PDT_2022
# Cuda compilation tools, release 11.8, V11.8.89
# Build cuda_11.8.r11.8/compiler.31833905_0

# %%
# !gcc -o hello -fopenmp code.c
# with math.h #gcc –o primos prog_omp_Numeros_Primos.c –fopenmp –O3 –std=c11 –lm
#./primos 5000000

# %%
# !./hello
# Out:
# Max Available Procs = 2
# Max Available Threads = 4
# Cláusula static SEM o parâmetro tam
# ID = 0 iteração = 0
# ID = 0 iteração = 1
# ID = 0 iteração = 2
# ID = 0 iteração = 3
# ID = 0 iteração = 4
# ID = 3 iteração = 15
# ID = 3 iteração = 16
# ID = 3 iteração = 17
# ID = 3 iteração = 18
# ID = 3 iteração = 19
# ID = 1 iteração = 5
# ID = 1 iteração = 6
# ID = 1 iteração = 7
# ID = 1 iteração = 8
# ID = 1 iteração = 9
# ID = 2 iteração = 10
# ID = 2 iteração = 11
# ID = 2 iteração = 12
# ID = 2 iteração = 13
# ID = 2 iteração = 14
# Cláusula static COM o parâmetro tam
# ID = 0 iteração = 0
# ID = 0 iteração = 1
# ID = 0 iteração = 2
# ID = 0 iteração = 12
# ID = 0 iteração = 13
# ID = 0 iteração = 14
# ID = 3 iteração = 9
# ID = 3 iteração = 10
# ID = 3 iteração = 11
# ID = 1 iteração = 3
# ID = 1 iteração = 4
# ID = 1 iteração = 5
# ID = 1 iteração = 15
# ID = 1 iteração = 16
# ID = 1 iteração = 17
# ID = 2 iteração = 6
# ID = 2 iteração = 7
# ID = 2 iteração = 8
# ID = 2 iteração = 18
# ID = 2 iteração = 19
